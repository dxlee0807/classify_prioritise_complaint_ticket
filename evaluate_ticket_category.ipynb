# %%
import pandas as pd
import os
import json
import re
import numpy as np

from gensim.models import Nmf
from gensim.models.ldamulticore import LdaMulticore
from top2vec import Top2Vec
from bertopic import BERTopic

from gensim.corpora.dictionary import Dictionary

# %%
def get_processed_df(csv_path):
    df = pd.read_csv(csv_path)
    return df

# %%
df = get_processed_df('process_csv_stage_2.csv')
df
# Out:
#        old_index                                  preprocessed_text  \
# 0              1  ['good', 'morning', 'name', 'appreciate', 'cou...
# 1              2  ['upgraded', 'card', 'tell', 'agent', 'upgrade...
# 2             10  ['chase', 'card', 'report', 'however', 'fraudu...
# 3             11  ['try', 'book', 'ticket', 'come', 'across', 'o...
# 4             14  ['grand', 'son', 'give', 'check', 'deposit', '...
# ...          ...                                                ...
# 21067      78303  ['chase', 'card', 'customer', 'well', 'decade'...
# 21068      78309  ['wednesday', 'call', 'chas', 'visa', 'credit'...
# 21069      78310  ['familiar', 'pay', 'understand', 'great', 'ri...
# 21070      78311  ['flawless', 'credit', 'chase', 'credit', 'car...
# 21071      78312  ['roughly', 'year', 'ago', 'close', 'account',...
#
#        topic_lda  topic_nmf  topic_t2v  topic_btp
# 0             22         11          0          0
# 1             26         10          0         44
# 2             33         12          0          0
# 3             26          7          0          0
# 4             25          4          0         56
# ...          ...        ...        ...        ...
# 21067         26         12          0          0
# 21068          2          9          0         26
# 21069         34          5          0         12
# 21070          7         10          0          1
# 21071         32          7          0         -1
#
# [21072 rows x 6 columns]

# %%
# load 4 topic models
load_lda = LdaMulticore.load(os.path.join(os.getcwd(),'topic_models',"final_lda"))
load_nmf = Nmf.load(os.path.join(os.getcwd(),'topic_models',"final_nmf"))
load_t2v = Top2Vec.load(os.path.join(os.getcwd(),'topic_models','final_t2v'))
load_bertopic = BERTopic.load(os.path.join(os.getcwd(),'topic_models','final_bertopic'))

load_lda_id2word = Dictionary.load(os.path.join(os.getcwd(),'topic_models',"final_lda.id2word"))

# %%
load_lda.show_topics(num_topics=-1, num_words=10,formatted=False)
# Out:
# [(0,
#   [('number', 0.045175977),
#    ('call', 0.044429593),
#    ('phone', 0.022473436),
#    ('mail', 0.020355199),
#    ('name', 0.019982629),
#    ('ask', 0.019960362),
#    ('say', 0.019025449),
#    ('information', 0.017310657),
#    ('address', 0.0172577),
#    ('card', 0.01657906)]),
#  (1,
#   [('receive', 0.042533588),
#    ('letter', 0.038389724),
#    ('call', 0.033241987),
#    ('send', 0.021684574),
#    ('would', 0.020890666),
#    ('state', 0.01941405),
#    ('request', 0.017950587),
#    ('day', 0.014303187),
#    ('time', 0.014046169),
#    ('contact', 0.0129366545)]),
#  (2,
#   [('item', 0.041874003),
#    ('order', 0.03923838),
#    ('return', 0.028201785),
#    ('purchase', 0.02439643),
#    ('receive', 0.017967032),
#    ('deliver', 0.014291601),
#    ('provide', 0.014221285),
#    ('package', 0.013579315),
#    ('amazon', 0.0133606),
#    ('ship', 0.013053289)]),
#  (3,
#   [('travel', 0.044437397),
#    ('benefit', 0.03801707),
#    ('card', 0.033077803),
#    ('ovid', 0.020756269),
#    ('trip', 0.01773028),
#    ('holder', 0.01691246),
#    ('pandemic', 0.015933411),
#    ('claim', 0.014213992),
#    ('due', 0.012347003),
#    ('use', 0.010913592)]),
#  (4,
#   [('transfer', 0.13035381),
#    ('account', 0.077511),
#    ('complaint', 0.021352047),
#    ('customer', 0.019196177),
#    ('service', 0.018358393),
#    ('department', 0.01385341),
#    ('request', 0.013135687),
#    ('executive', 0.011881836),
#    ('number', 0.011467139),
#    ('provide', 0.010825999)]),
#  (5,
#   [('fraud', 0.11424457),
#    ('signature', 0.032904193),
#    ('daughter', 0.028027954),
#    ('case', 0.022027038),
#    ('document', 0.01879509),
#    ('police', 0.015125627),
#    ('ing', 0.01303263),
#    ('name', 0.012790328),
#    ('use', 0.011616826),
#    ('sign', 0.011109474)]),
#  (6,
#   [('account', 0.23322318),
#    ('close', 0.08502075),
#    ('open', 0.043940097),
#    ('bank', 0.023040067),
#    ('reason', 0.014146269),
#    ('check', 0.0120829865),
#    ('card', 0.011431682),
#    ('without', 0.010941039),
#    ('credit', 0.008962953),
#    ('letter', 0.008708738)]),
#  (7,
#   [('interest', 0.062191587),
#    ('balance', 0.054792088),
#    ('pay', 0.0474929),
#    ('payment', 0.031878714),
#    ('charge', 0.030209739),
#    ('statement', 0.024351325),
#    ('rate', 0.021907149),
#    ('fee', 0.021884639),
#    ('card', 0.021522919),
#    ('month', 0.017741848)]),
#  (8,
#   [('refund', 0.090138435),
#    ('cancel', 0.051060718),
#    ('ticket', 0.029018968),
#    ('charge', 0.028672725),
#    ('flight', 0.027169688),
#    ('credit', 0.026953982),
#    ('card', 0.023779364),
#    ('issue', 0.013012652),
#    ('book', 0.012403208),
#    ('purchase', 0.01217251)]),
#  (9,
#   [('charge', 0.116269514),
#    ('card', 0.077821866),
#    ('credit', 0.03483155),
#    ('fraudulent', 0.025827227),
#    ('fraud', 0.023527019),
#    ('purchase', 0.022075944),
#    ('make', 0.020607457),
#    ('transaction', 0.018588753),
#    ('account', 0.012164294),
#    ('authorize', 0.011247871)]),
#  (10,
#   [('mortgage', 0.036510892),
#    ('loan', 0.033876076),
#    ('home', 0.02588653),
#    ('modification', 0.023164095),
#    ('payment', 0.017109195),
#    ('year', 0.016005682),
#    ('sale', 0.013691437),
#    ('house', 0.012461737),
#    ('foreclosure', 0.011698634),
#    ('time', 0.011559229)]),
#  (11,
#   [('claim', 0.08478082),
#    ('transaction', 0.052126445),
#    ('account', 0.025913496),
#    ('bank', 0.024835806),
#    ('money', 0.024077864),
#    ('file', 0.021358658),
#    ('fraud', 0.021022256),
#    ('report', 0.018250922),
#    ('police', 0.016799208),
#    ('back', 0.014260822)]),
#  (12,
#   [('husband', 0.031334385),
#    ('jpmorgan', 0.024943236),
#    ('time', 0.01221553),
#    ('morgan', 0.008499457),
#    ('even', 0.007983305),
#    ('customer', 0.0078753345),
#    ('name', 0.007850697),
#    ('request', 0.007291681),
#    ('way', 0.007281285),
#    ('write', 0.0071845674)]),
#  (13,
#   [('email', 0.07263919),
#    ('send', 0.04060832),
#    ('message', 0.036451776),
#    ('address', 0.032042183),
#    ('number', 0.025777504),
#    ('phone', 0.025088966),
#    ('via', 0.023011688),
#    ('receive', 0.019926945),
#    ('online', 0.018286737),
#    ('account', 0.016693456)]),
#  (14,
#   [('debt', 0.1212267),
#    ('pay', 0.07436267),
#    ('owe', 0.057663072),
#    ('balance', 0.05028291),
#    ('account', 0.039435156),
#    ('amount', 0.036687613),
#    ('collection', 0.030936334),
#    ('report', 0.022797009),
#    ('full', 0.018882066),
#    ('irs', 0.0185678)]),
#  (15,
#   [('car', 0.06950833),
#    ('vehicle', 0.03412122),
#    ('lease', 0.0272883),
#    ('auto', 0.022845011),
#    ('finance', 0.01929858),
#    ('pay', 0.018616637),
#    ('insurance', 0.01808632),
#    ('title', 0.016125277),
#    ('rental', 0.013333641),
#    ('damage', 0.012935987)]),
#  (16,
#   [('bank', 0.14579669),
#    ('morgan', 0.044174787),
#    ('wire', 0.033147696),
#    ('fund', 0.025093013),
#    ('send', 0.014564588),
#    ('transfer', 0.012247001),
#    ('department', 0.00932311),
#    ('money', 0.009244627),
#    ('account', 0.008542329),
#    ('return', 0.0083726775)]),
#  (17,
#   [('call', 0.04760875),
#    ('access', 0.045989882),
#    ('online', 0.029604558),
#    ('phone', 0.029379657),
#    ('account', 0.027180946),
#    ('hour', 0.01900436),
#    ('time', 0.017597213),
#    ('hold', 0.014311531),
#    ('try', 0.01329057),
#    ('block', 0.012000425)]),
#  (18,
#   [('dispute', 0.12088592),
#    ('merchant', 0.06710434),
#    ('charge', 0.04630496),
#    ('service', 0.040875185),
#    ('provide', 0.03198699),
#    ('company', 0.02887429),
#    ('amount', 0.014848018),
#    ('credit', 0.013930664),
#    ('documentation', 0.013244041),
#    ('bill', 0.0124996845)]),
#  (19,
#   [('mortgage', 0.053546816),
#    ('escrow', 0.0402646),
#    ('tax', 0.0394884),
#    ('pay', 0.03333348),
#    ('insurance', 0.03013795),
#    ('payment', 0.026601788),
#    ('property', 0.024679506),
#    ('amount', 0.0141736735),
#    ('loan', 0.012568819),
#    ('year', 0.010785976)]),
#  (20,
#   [('scam', 0.039679103),
#    ('company', 0.028955882),
#    ('bank', 0.02379722),
#    ('people', 0.015988013),
#    ('work', 0.015903477),
#    ('move', 0.0137403095),
#    ('contract', 0.013545519),
#    ('pay', 0.0096259685),
#    ('complaint', 0.009405195),
#    ('get', 0.008698883)]),
#  (21,
#   [('bank', 0.015438305),
#    ('attorney', 0.01531696),
#    ('court', 0.014267161),
#    ('document', 0.012552095),
#    ('loan', 0.012287106),
#    ('file', 0.010755083),
#    ('note', 0.009535541),
#    ('record', 0.009499233),
#    ('state', 0.009052401),
#    ('legal', 0.008611095)]),
#  (22,
#   [('money', 0.048720665),
#    ('get', 0.03568861),
#    ('account', 0.02435369),
#    ('bank', 0.023711836),
#    ('say', 0.02346175),
#    ('back', 0.018671758),
#    ('pay', 0.016576663),
#    ('take', 0.016278481),
#    ('tell', 0.015714187),
#    ('help', 0.015077495)]),
#  (23,
#   [('fee', 0.1012765),
#    ('account', 0.049451843),
#    ('charge', 0.046827435),
#    ('bank', 0.024384353),
#    ('overdraft', 0.023947384),
#    ('fund', 0.02268129),
#    ('transaction', 0.022438858),
#    ('day', 0.018379778),
#    ('time', 0.012999883),
#    ('check', 0.012217091)]),
#  (24,
#   [('account', 0.08584681),
#    ('branch', 0.051578965),
#    ('business', 0.02582704),
#    ('open', 0.025784282),
#    ('bank', 0.024939263),
#    ('banker', 0.019824317),
#    ('personal', 0.014311351),
#    ('deposit', 0.012679513),
#    ('manager', 0.012385019),
#    ('would', 0.01184196)]),
#  (25,
#   [('check', 0.11834372),
#    ('deposit', 0.047558524),
#    ('bank', 0.047462758),
#    ('account', 0.042508364),
#    ('fund', 0.031751677),
#    ('money', 0.018107973),
#    ('cash', 0.017249122),
#    ('day', 0.013780269),
#    ('branch', 0.013000873),
#    ('tell', 0.011451646)]),
#  (26,
#   [('card', 0.050037082),
#    ('offer', 0.038874328),
#    ('point', 0.030620236),
#    ('credit', 0.021721676),
#    ('reward', 0.018811459),
#    ('receive', 0.01612333),
#    ('bonus', 0.0156047605),
#    ('apply', 0.014236693),
#    ('would', 0.011959564),
#    ('first', 0.011801193)]),
#  (27,
#   [('call', 0.0741171),
#    ('tell', 0.054860316),
#    ('say', 0.052307453),
#    ('would', 0.03864065),
#    ('get', 0.033165302),
#    ('ask', 0.027778156),
#    ('could', 0.02643019),
#    ('back', 0.024336243),
#    ('speak', 0.01840107),
#    ('time', 0.01234416)]),
#  (28,
#   [('card', 0.0743846),
#    ('debit', 0.047546763),
#    ('atm', 0.030921038),
#    ('account', 0.027179327),
#    ('use', 0.02360288),
#    ('bank', 0.02285043),
#    ('withdrawal', 0.020555707),
#    ('transaction', 0.017671963),
#    ('make', 0.01677349),
#    ('pin', 0.01284205)]),
#  (29,
#   [('credit', 0.14589289),
#    ('card', 0.11537137),
#    ('score', 0.018468624),
#    ('apply', 0.014718933),
#    ('limit', 0.01421472),
#    ('year', 0.011899526),
#    ('application', 0.011574631),
#    ('use', 0.010988813),
#    ('bank', 0.009668306),
#    ('time', 0.008334075)]),
#  (30,
#   [('consumer', 0.03491795),
#    ('act', 0.020043956),
#    ('law', 0.016486794),
#    ('state', 0.012124627),
#    ('agreement', 0.0120301405),
#    ('provide', 0.011912455),
#    ('federal', 0.011447702),
#    ('practice', 0.011122064),
#    ('violation', 0.011102031),
#    ('information', 0.01103806)]),
#  (31,
#   [('loan', 0.05986125),
#    ('rate', 0.02092383),
#    ('mortgage', 0.014544048),
#    ('application', 0.013812716),
#    ('would', 0.012634359),
#    ('process', 0.011709465),
#    ('close', 0.011207119),
#    ('refinance', 0.010939992),
#    ('closing', 0.010691545),
#    ('home', 0.009286259)]),
#  (32,
#   [('payment', 0.14044899),
#    ('late', 0.037904132),
#    ('make', 0.033330638),
#    ('pay', 0.026811492),
#    ('credit', 0.026242767),
#    ('due', 0.020191522),
#    ('account', 0.017845355),
#    ('month', 0.016082555),
#    ('report', 0.015484818),
#    ('time', 0.013740042)]),
#  (33,
#   [('report', 0.10137294),
#    ('credit', 0.100172095),
#    ('inquiry', 0.03671617),
#    ('remove', 0.027099412),
#    ('information', 0.024868844),
#    ('reporting', 0.019699564),
#    ('bureau', 0.01616933),
#    ('request', 0.015421329),
#    ('company', 0.014525728),
#    ('account', 0.01434487)]),
#  (34,
#   [('would', 0.024564449),
#    ('could', 0.011469371),
#    ('time', 0.008958111),
#    ('make', 0.008672412),
#    ('pay', 0.0086398125),
#    ('box', 0.008636413),
#    ('use', 0.008021231),
#    ('one', 0.007170791),
#    ('also', 0.0064191),
#    ('amount', 0.00630511)])]

# %%
load_nmf.show_topics(num_topics=-1, num_words=10,formatted=False)
# Out:
# [(0,
#   [('payment', 0.1477028716568463),
#    ('bank', 0.04879491467247396),
#    ('mortgage', 0.03523791870658215),
#    ('make', 0.03174185876243133),
#    ('pay', 0.030653416368943486),
#    ('late', 0.021119967739925173),
#    ('month', 0.02026675839407351),
#    ('loan', 0.01554597313773468),
#    ('due', 0.014913002712180136),
#    ('year', 0.014905893992374684)]),
#  (1,
#   [('charge', 0.043812247216827575),
#    ('dispute', 0.029672381997809125),
#    ('receive', 0.02249371929340892),
#    ('letter', 0.016614540762213317),
#    ('fee', 0.015187347689960197),
#    ('state', 0.01496472065369569),
#    ('date', 0.01389269686530772),
#    ('provide', 0.013642209479140749),
#    ('merchant', 0.011904249786874837),
#    ('refund', 0.01169346029256579)]),
#  (2,
#   [('call', 0.043169911781447974),
#    ('would', 0.04255644980244704),
#    ('get', 0.04159881635216732),
#    ('say', 0.03748529547226943),
#    ('tell', 0.02560222025607286),
#    ('back', 0.019492796477472173),
#    ('could', 0.018103046486278335),
#    ('time', 0.017256420099915584),
#    ('pay', 0.016850526476552857),
#    ('ask', 0.016450942785758465)]),
#  (3,
#   [('loan', 0.05155737738041796),
#    ('mortgage', 0.021476040271265755),
#    ('home', 0.015191317375274752),
#    ('modification', 0.014370533479717151),
#    ('property', 0.013132734038720945),
#    ('document', 0.012158161420738237),
#    ('borrower', 0.00890837588163206),
#    ('sale', 0.007626652443464625),
#    ('rate', 0.007596412575143784),
#    ('foreclosure', 0.0075582973719561354)]),
#  (4,
#   [('check', 0.19020128889478857),
#    ('deposit', 0.04291548477385032),
#    ('day', 0.029571848456035384),
#    ('fund', 0.0254524210964181),
#    ('cash', 0.01828545063430759),
#    ('money', 0.015548943498754374),
#    ('amount', 0.012648896685206329),
#    ('pay', 0.012470625395113547),
#    ('clear', 0.010467626834758749),
#    ('hold', 0.010296733863692314)]),
#  (5,
#   [('account', 0.06632414648086854),
#    ('bank', 0.05288670219489723),
#    ('fraud', 0.04106890691021168),
#    ('money', 0.034925808902623284),
#    ('charge', 0.0348400616613987),
#    ('use', 0.01941848066804601),
#    ('customer', 0.017375148485655998),
#    ('fund', 0.0157067605942618),
#    ('transfer', 0.015432604967653174),
#    ('deposit', 0.01425636262380968)]),
#  (6,
#   [('report', 0.04196925949374273),
#    ('consumer', 0.024484431203977614),
#    ('act', 0.02122120822896201),
#    ('information', 0.019490946809255442),
#    ('request', 0.01861848772530262),
#    ('reporting', 0.0164206948785338),
#    ('agency', 0.013943576149898333),
#    ('fair', 0.013557863055070929),
#    ('collection', 0.013550144724063852),
#    ('debt', 0.0127484069964727)]),
#  (7,
#   [('account', 0.11381123344737445),
#    ('credit', 0.11191117627905406),
#    ('report', 0.03674342419314486),
#    ('close', 0.03513095447761024),
#    ('open', 0.03018256517273692),
#    ('issue', 0.01353517341652054),
#    ('check', 0.012669214691302787),
#    ('letter', 0.011285216218760183),
#    ('reason', 0.0108273014257168),
#    ('name', 0.010159953640920911)]),
#  (8,
#   [('card', 0.14866383934958044),
#    ('service', 0.01914297190937308),
#    ('use', 0.016152953946082536),
#    ('fraud', 0.014338644272065257),
#    ('charge', 0.013686470761012714),
#    ('point', 0.008082901848245765),
#    ('receive', 0.007724395667347373),
#    ('purchase', 0.006997525431573453),
#    ('customer', 0.006748815484115867),
#    ('program', 0.006660319518394338)]),
#  (9,
#   [('claim', 0.05591358578071828),
#    ('call', 0.023810575408152512),
#    ('number', 0.021400584089903692),
#    ('department', 0.01716165395298073),
#    ('transaction', 0.01684015885016281),
#    ('say', 0.015809849652532466),
#    ('file', 0.01417221921055192),
#    ('email', 0.013825688309304668),
#    ('information', 0.013482473106219344),
#    ('make', 0.013105899556606257)]),
#  (10,
#   [('card', 0.07649504235172712),
#    ('make', 0.04551630114425749),
#    ('transaction', 0.039722433166432085),
#    ('balance', 0.03794990435220553),
#    ('fee', 0.03303990394868986),
#    ('payment', 0.0323532336169119),
#    ('purchase', 0.025713226203104508),
#    ('account', 0.02151271078896459),
#    ('pay', 0.018607221207348573),
#    ('interest', 0.01855094870013451)]),
#  (11,
#   [('bank', 0.06234141684893939),
#    ('send', 0.03396370248346327),
#    ('would', 0.03249911956919385),
#    ('tell', 0.028885747628941857),
#    ('money', 0.020914184956598893),
#    ('back', 0.019294485783650336),
#    ('get', 0.015408322651893857),
#    ('could', 0.014902172378812998),
#    ('ask', 0.013066200418156393),
#    ('contact', 0.012207952625398926)]),
#  (12,
#   [('credit', 0.20808358973466762),
#    ('card', 0.04772009280399762),
#    ('charge', 0.018846102754971606),
#    ('consumer', 0.014096073929997706),
#    ('report', 0.013661384108334285),
#    ('score', 0.01329225073387883),
#    ('limit', 0.01244274479043296),
#    ('pay', 0.01207182291569656),
#    ('company', 0.010703143499540645),
#    ('inquiry', 0.009156063657493156)]),
#  (13,
#   [('call', 0.06767660283816301),
#    ('receive', 0.0442911269637813),
#    ('tell', 0.03109697885941389),
#    ('day', 0.025355041089504534),
#    ('service', 0.017827659595755024),
#    ('ask', 0.017429729160526236),
#    ('customer', 0.016845294412489248),
#    ('phone', 0.015248579657112559),
#    ('mail', 0.013793735957421366),
#    ('could', 0.011606686169394066)]),
#  (14,
#   [('account', 0.22392598739260863),
#    ('close', 0.025605956291053077),
#    ('open', 0.019297933765798178),
#    ('fund', 0.014518285627148301),
#    ('branch', 0.01195554928248106),
#    ('state', 0.01179839399872494),
#    ('request', 0.011753862984138904),
#    ('service', 0.011714342353441948),
#    ('deposit', 0.011238828969494845),
#    ('business', 0.01022794635596176)])]

# %%
t2v_topics_words, t2v_word_scores, t2v_topic_nums = load_t2v.get_topics()

# %%
t2v_topics_words
# Out:
# array([['chexsystems', 'cfpb', 'autopay', 'bofa', 'lifelock', 'usaa',
#         'citibank', 'repoed', 'chase', 'wamu', 'overdrawn', 'kyc',
#         'wellsfargo', 'transunion', 'garnishment', 'preapproval', 'pnc',
#         'experian', 'chargebacks', 'echeck', 'churning', 'defaulted',
#         'citi', 'overdrafted', 'garnishments', 'overdrafts',
#         'chargeback', 'overdraft', 'garnished', 'refinanced', 'bank',
#         'defrauded', 'fdic', 'creditor', 'creditors', 'heloc', 'banking',
#         'reposession', 'refi', 'insolvent', 'equifax', 'creditcard',
#         'debtors', 'amex', 'receivables', 'santander', 'overdraw',
#         'fraudsters', 'lender', 'hsbc'],
#        ['experian', 'dispute', 'lifelock', 'transunion', 'garnishment',
#         'creditor', 'chexsystems', 'equifax', 'defrauded', 'repoed',
#         'receivables', 'disputes', 'garnished', 'creditors', 'disputing',
#         'litigation', 'garnishing', 'collections', 'fraudulent',
#         'bureaus', 'autopay', 'forclosure', 'debtor', 'bailiff',
#         'bankrupcy', 'cfpb', 'refile', 'garnishments', 'reposession',
#         'lein', 'credit', 'repossession', 'owed', 'ombudsman',
#         'nonpayment', 'forclosed', 'adjudicated', 'defrauding',
#         'bailiffs', 'bbb', 'disputed', 'evidences', 'paystubs',
#         'subpoenaed', 'echeck', 'deferral', 'rma', 'defaulted',
#         'postmarked', 'repossess'],
#        ['creditor', 'autopay', 'creditors', 'debtor', 'debt',
#         'indebtedness', 'debts', 'debtors', 'credit', 'garnished',
#         'acct', 'garnishment', 'creditcard', 'billing', 'chexsystems',
#         'invoices', 'chargeback', 'repoed', 'garnishing', 'cosigned',
#         'lifelock', 'debit', 'transunion', 'experian', 'iasked',
#         'reposession', 'invoicing', 'accts', 'lein', 'accounts',
#         'defaulted', 'cfpb', 'signature', 'bankrupcy', 'acount', 'owed',
#         'relinquishing', 'cosigner', 'invoice', 'account', 'chargebacks',
#         'kyc', 'overdrawn', 'insolvent', 'repossess', 'insolvency',
#         'citibank', 'garnishments', 'debits', 'receivables'],
#        ['transunion', 'autopay', 'chexsystems', 'cfpb', 'preapproval',
#         'heloc', 'equifax', 'credit', 'wellsfargo', 'refi', 'experian',
#         'citibank', 'prepayment', 'lifelock', 'lender', 'refinanced',
#         'leveraged', 'lenders', 'subprime', 'ssn', 'reposession',
#         'defaulted', 'refinancing', 'lending', 'preapproved',
#         'crediting', 'underwriter', 'overdrawn', 'overdrafted',
#         'documented', 'loan', 'depositing', 'cosigner', 'defrauding',
#         'direct', 'citi', 'fico', 'fdic', 'annualized', 'fraudulent',
#         'defrauded', 'treasuries', 'pnc', 'deposited', 'repoed',
#         'banker', 'stimulas', 'overdraw', 'insolvency', 'resubmitted'],
#        ['preapproval', 'autopay', 'chexsystems', 'refi', 'cfpb',
#         'forclosure', 'lender', 'repoed', 'rejections', 'nonpayment',
#         'rejecting', 'reposession', 'citibank', 'payment', 'payments',
#         'repossesion', 'refinanced', 'insolvent', 'foreclosure',
#         'santander', 'experian', 'garnishments', 'wellsfargo',
#         'counteroffer', 'paiement', 'heloc', 'transunion', 'defaulted',
#         'refused', 'echeck', 'refinance', 'delinquent', 'equifax',
#         'bofa', 'overdrafted', 'mortgages', 'rejection', 'mortgage',
#         'underwriter', 'prepayment', 'bank', 'forclosed', 'wamu',
#         'declined', 'credit', 'repossession', 'usaa', 'foreclose',
#         'creditors', 'creditcard'],
#        ['verified', 'unverified', 'verifications', 'verifies', 'chase',
#         'echeck', 'verification', 'chexsystems', 'confirmations',
#         'fraudulent', 'scam', 'fraudsters', 'verifying', 'autopay',
#         'validated', 'phished', 'fraudster', 'doolie', 'reactivated',
#         'confirming', 'acct', 'investigators', 'transparently',
#         'reactivate', 'accounts', 'audited', 'investigated', 'confirm',
#         'cfpb', 'phising', 'recd', 'lifelock', 'confirmatory', 'scammer',
#         'cancell', 'audits', 'idenity', 'investigations', 'cheques',
#         'responded', 'account', 'checks', 'defrauded', 'subsidiaries',
#         'usaa', 'accts', 'denials', 'amex', 'forged', 'authenticating'],
#        ['usc', 'chexsystems', 'creditor', 'transunion', 'warrents',
#         'chase', 'garnishment', 'lifelock', 'creditors', 'snitching',
#         'bankrupcy', 'arrests', 'bureaus', 'repoed', 'experian',
#         'equifax', 'reposession', 'defaulted', 'garnishments',
#         'garnished', 'debtors', 'flagged', 'trespassing', 'sued',
#         'prosecuted', 'trespass', 'overdrafted', 'crediting', 'ssn',
#         'repossession', 'collections', 'indebtedness', 'extradition',
#         'chases', 'collection', 'garnishing', 'infringement',
#         'misdemeanor', 'bofa', 'infraction', 'extradite', 'credit',
#         'offenses', 'violating', 'delinquent', 'harassing', 'reposessed',
#         'chasing', 'receivables', 'repossess']], dtype='<U14')

# %%
t2v_word_scores
# Out:
# array([[0.46370572, 0.43605196, 0.42608595, 0.41304153, 0.4008296 ,
#         0.38632601, 0.38542113, 0.38200244, 0.37864625, 0.37788004,
#         0.3770043 , 0.37140572, 0.37052795, 0.36970824, 0.3658105 ,
#         0.3594699 , 0.35657394, 0.35613358, 0.35557187, 0.35363078,
#         0.34866542, 0.34795815, 0.34740597, 0.34513932, 0.34031385,
#         0.3396248 , 0.33903915, 0.3389546 , 0.33420798, 0.33093202,
#         0.33005804, 0.32784072, 0.3278141 , 0.32628638, 0.32610303,
#         0.32451338, 0.32425547, 0.32315218, 0.32305908, 0.3218513 ,
#         0.3213454 , 0.32028922, 0.31769252, 0.3176263 , 0.31715724,
#         0.3154136 , 0.30872297, 0.30864674, 0.30856234, 0.30735195],
#        [0.38854337, 0.36430746, 0.35050845, 0.34649712, 0.3195392 ,
#         0.31505477, 0.31088   , 0.30386302, 0.30373734, 0.29891717,
#         0.29870796, 0.29715556, 0.29332998, 0.29220495, 0.28834844,
#         0.28606564, 0.28340527, 0.2814926 , 0.28024864, 0.279635  ,
#         0.2780338 , 0.27792847, 0.27776366, 0.2761129 , 0.2756856 ,
#         0.27552122, 0.27311075, 0.27298746, 0.2720714 , 0.26915038,
#         0.26785138, 0.26736176, 0.2666367 , 0.2653465 , 0.26404366,
#         0.26377097, 0.262852  , 0.26069233, 0.2603424 , 0.25810543,
#         0.25802925, 0.25640255, 0.25619775, 0.2556715 , 0.25506675,
#         0.2546446 , 0.25456026, 0.254003  , 0.25347584, 0.25274158],
#        [0.3812989 , 0.35971606, 0.35294774, 0.34953153, 0.33854353,
#         0.3247568 , 0.3200302 , 0.30951452, 0.30787432, 0.30492893,
#         0.30459535, 0.2986527 , 0.2974937 , 0.29508594, 0.29489222,
#         0.28907353, 0.28509694, 0.28292015, 0.28176206, 0.280057  ,
#         0.27993807, 0.2770725 , 0.27519885, 0.27376154, 0.27307916,
#         0.27091658, 0.26920277, 0.26881844, 0.26826555, 0.2674323 ,
#         0.26740706, 0.26692745, 0.26649007, 0.262904  , 0.26015374,
#         0.25981003, 0.2589172 , 0.25685567, 0.25274843, 0.25026602,
#         0.24774635, 0.24764912, 0.24755862, 0.24732406, 0.24571198,
#         0.24534672, 0.24500275, 0.24495292, 0.24470355, 0.24376848],
#        [0.36027545, 0.33422676, 0.32685494, 0.31421548, 0.31072956,
#         0.30432013, 0.29801643, 0.29765144, 0.29326072, 0.28750092,
#         0.28634453, 0.2860406 , 0.28450632, 0.28321058, 0.28196734,
#         0.2786896 , 0.27133948, 0.2642727 , 0.257805  , 0.25762868,
#         0.25588518, 0.25521252, 0.25496864, 0.25493318, 0.25398847,
#         0.2519698 , 0.25051218, 0.24922371, 0.24847329, 0.24611172,
#         0.24493076, 0.2424272 , 0.24150017, 0.23965374, 0.23931691,
#         0.23868647, 0.2383168 , 0.23829734, 0.23795769, 0.23769963,
#         0.23746352, 0.23718017, 0.23705791, 0.2369699 , 0.23694979,
#         0.2367388 , 0.23641275, 0.23562044, 0.23542005, 0.2353518 ],
#        [0.3533603 , 0.3275693 , 0.32338923, 0.30550742, 0.29975632,
#         0.29777837, 0.29525983, 0.29248554, 0.2921734 , 0.29205638,
#         0.29103437, 0.28753692, 0.28583068, 0.28530484, 0.28316003,
#         0.28275883, 0.28217116, 0.28168023, 0.27971637, 0.27948612,
#         0.2782289 , 0.27687174, 0.27595788, 0.2732149 , 0.27250504,
#         0.2719283 , 0.27130964, 0.27105972, 0.2706473 , 0.2703945 ,
#         0.2700535 , 0.26983202, 0.26798946, 0.2672399 , 0.26615396,
#         0.26493382, 0.2637552 , 0.26232377, 0.26181996, 0.26075283,
#         0.26019898, 0.25945836, 0.2593205 , 0.25888765, 0.2588456 ,
#         0.25865352, 0.2583896 , 0.25812632, 0.25790724, 0.25789714],
#        [0.34254855, 0.33908823, 0.3314915 , 0.3169883 , 0.31075376,
#         0.30632114, 0.3053258 , 0.30400777, 0.30088437, 0.29316235,
#         0.29222563, 0.28120935, 0.28069293, 0.2746956 , 0.27427056,
#         0.27384162, 0.27295715, 0.27267984, 0.26788384, 0.26736268,
#         0.26664364, 0.26488167, 0.264544  , 0.26420942, 0.26413333,
#         0.26270485, 0.26258737, 0.2623028 , 0.25665146, 0.25618488,
#         0.2561649 , 0.2547181 , 0.25390443, 0.25332358, 0.25249422,
#         0.25237244, 0.25212663, 0.25141543, 0.24932748, 0.24846204,
#         0.2480934 , 0.24798891, 0.24713807, 0.24664834, 0.24651429,
#         0.246508  , 0.24643567, 0.24579489, 0.24420166, 0.24375534],
#        [0.3837677 , 0.3313076 , 0.32666308, 0.3032295 , 0.29860133,
#         0.29640013, 0.29337594, 0.29024202, 0.28892213, 0.28718677,
#         0.2860462 , 0.28272092, 0.28227615, 0.2789079 , 0.27370265,
#         0.2730878 , 0.27295327, 0.2716471 , 0.27046242, 0.26102155,
#         0.25984788, 0.2596302 , 0.25942755, 0.2589754 , 0.256168  ,
#         0.25554922, 0.25475162, 0.2537759 , 0.25358665, 0.25313368,
#         0.25272918, 0.252158  , 0.2519685 , 0.24945447, 0.24627575,
#         0.24595554, 0.24562994, 0.24529919, 0.24489143, 0.2447016 ,
#         0.243446  , 0.2425715 , 0.24176408, 0.24062441, 0.2396878 ,
#         0.23903424, 0.23893651, 0.23807222, 0.23501323, 0.23421216]],
#       dtype=float32)

# %%
t2v_topic_nums
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
load_bertopic.get_topic_info()
