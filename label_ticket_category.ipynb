# %%
import pandas as pd
import os
import json
import re
import numpy as np

from gensim.models import Nmf
from gensim.models.ldamulticore import LdaMulticore
from top2vec import Top2Vec
from bertopic import BERTopic

from gensim.corpora.dictionary import Dictionary

# %%
# load raw complaint json into raw df 
raw = pd.json_normalize(json.load(open("complaints-2021-05-14_08_16_.json")))

# renaming column
raw.columns = ['index', 'type', 'id', 'score', 'tags', 'zip_code','complaint_id', 'issue', 'date_received',
       'state', 'consumer_disputed', 'product','company_response', 'company', 'submitted_via',
       'date_sent_to_company', 'company_public_response','sub_product', 'timely',
       'complaint_what_happened', 'sub_issue','consumer_consent_provided']

# drop unnecessary columns
raw.drop(['index', 'type', 'id', 'score', 'tags', 'zip_code','complaint_id', 'issue', 'date_received',
       'state', 'consumer_disputed', 'product','company_response', 'company', 'submitted_via',
       'date_sent_to_company', 'company_public_response','sub_product', 'timely',
       'sub_issue','consumer_consent_provided'],axis=1,inplace=True)

# drop null values
raw['complaint_what_happened'].replace(r'^\s*$', np.nan, regex=True, inplace=True)
raw.dropna(inplace=True)

# clear masked values
def remove_mask(text):
    masked_text_pattern = r"\b[x|X]{2,20}"
    return re.sub(masked_text_pattern,'',text)

removed_mask = raw.complaint_what_happened.apply(remove_mask)

# %%
# import process_csv_stage_1.csv
df = pd.read_csv('process_csv_stage_1.csv')
df.columns = ['old_index','preprocessed_text']
df
# Out:
#        old_index                                  preprocessed_text
# 0              1  good morning name appreciate could help put st...
# 1              2  upgraded card tell agent upgrade anniversary d...
# 2             10  chase card report however fraudulent applicati...
# 3             11  try book ticket come across offer apply toward...
# 4             14  grand son give check deposit chase account fun...
# ...          ...                                                ...
# 21067      78303  chase card customer well decade offer multiple...
# 21068      78309  wednesday call chas visa credit card provider ...
# 21069      78310  familiar pay understand great risk provide con...
# 21070      78311  flawless credit chase credit card chase freedo...
# 21071      78312  roughly year ago close account morgan chase ba...
#
# [21072 rows x 2 columns]

# %%
# test_string = df[df['old_index']==42]['preprocessed_text']
df['preprocessed_text'][df[df['old_index']==42].index[0]]
# print(test_string.index)
# Out:
# 'card miss realize today check email say deposit money take bank account'

# %%
# load 4 topic models
load_lda = LdaMulticore.load(os.path.join(os.getcwd(),'topic_models',"final_lda"))
load_nmf = Nmf.load(os.path.join(os.getcwd(),'topic_models',"final_nmf"))
load_t2v = Top2Vec.load(os.path.join(os.getcwd(),'topic_models','final_t2v'))
load_bertopic = BERTopic.load(os.path.join(os.getcwd(),'topic_models','final_bertopic'))

# %% [markdown]
# - label generated topics to the df
# - resulting df: preprocessed_text | topic_nmf | topic_lda | topic_t2v | topic_btp
# - and their index-topic matrix

# %%
load_lda_id2word = Dictionary.load(os.path.join(os.getcwd(),'topic_models',"final_lda.id2word"))

# %%
for i in load_lda_id2word.iteritems():
    print(i)
# Out:
# (0, 'acceptable')
# (1, 'account')
# (2, 'advance')
# (3, 'appreciate')
# (4, 'ask')
# (5, 'attempt')
# (6, 'bank')
# (7, 'card')
# (8, 'collect')
# (9, 'consumer')
# (10, 'could')
# (11, 'debt')
# (12, 'every')
# (13, 'good')
# (14, 'help')
# (15, 'information')
# (16, 'instead')
# (17, 'know')
# (18, 'mail')
# (19, 'member')
# (20, 'month')
# (21, 'morning')
# (22, 'name')
# (23, 'put')
# (24, 'receive')
# (25, 'right')
# (26, 'send')
# (27, 'service')
# (28, 'statement')
# (29, 'stop')
# (30, 'thanks')
# (31, 'validate')
# (32, 'verification')
# (33, 'write')
# (34, 'agent')
# (35, 'anniversary')
# (36, 'change')
# (37, 'consent')
# (38, 'date')
# (39, 'give')
# (40, 'mislead')
# (41, 'order')
# (42, 'record')
# (43, 'tell')
# (44, 'turned')
# (45, 'upgrade')
# (46, 'upgraded')
# (47, 'without')
# (48, 'would')
# (49, 'wrong')
# (50, 'applicant')
# (51, 'application')
# (52, 'credit')
# (53, 'extend')
# (54, 'fraudulent')
# (55, 'fraudulently')
# (56, 'however')
# (57, 'identity')
# (58, 'obtain')
# (59, 'report')
# (60, 'submit')
# (61, 'verify')
# (62, 'absolutely')
# (63, 'across')
# (64, 'ahead')
# (65, 'apply')
# (66, 'approve')
# (67, 'book')
# (68, 'come')
# (69, 'contact')
# (70, 'contacted')
# (71, 'contrary')
# (72, 'correct')
# (73, 'decision')
# (74, 'deny')
# (75, 'error')
# (76, 'even')
# (77, 'explain')
# (78, 'explicit')
# (79, 'explicitly')
# (80, 'fact')
# (81, 'first')
# (82, 'get')
# (83, 'glad')
# (84, 'happen')
# (85, 'immediately')
# (86, 'interested')
# (87, 'later')
# (88, 'less')
# (89, 'longer')
# (90, 'make')
# (91, 'min')
# (92, 'minute')
# (93, 'notification')
# (94, 'notified')
# (95, 'notwithstanding')
# (96, 'oblige')
# (97, 'offer')
# (98, 'open')
# (99, 'proceed')
# (100, 'process')
# (101, 'purchase')
# (102, 'refer')
# (103, 'refuse')
# (104, 'representative')
# (105, 'request')
# (106, 'reward')
# (107, 'screen')
# (108, 'spoke')
# (109, 'state')
# (110, 'though')
# (111, 'ticket')
# (112, 'towards')
# (113, 'try')
# (114, 'use')
# (115, 'via')
# (116, 'withdrawn')
# (117, 'within')
# (118, 'call')
# (119, 'check')
# (120, 'claim')
# (121, 'clear')
# (122, 'close')
# (123, 'country')
# (124, 'deposit')
# (125, 'fund')
# (126, 'grand')
# (127, 'money')
# (128, 'need')
# (129, 'never')
# (130, 'number')
# (131, 'owner')
# (132, 'pay')
# (133, 'peek')
# (134, 'say')
# (135, 'son')
# (136, 'take')
# (137, 'time')
# (138, 'inquiry')
# (139, 'please')
# (140, 'remove')
# (141, 'actually')
# (142, 'additional')
# (143, 'advise')
# (144, 'affect')
# (145, 'although')
# (146, 'associate')
# (147, 'assure')
# (148, 'available')
# (149, 'believe')
# (150, 'bind')
# (151, 'branch')
# (152, 'business')
# (153, 'car')
# (154, 'current')
# (155, 'currently')
# (156, 'customer')
# (157, 'day')
# (158, 'deal')
# (159, 'debit')
# (160, 'direct')
# (161, 'document')
# (162, 'employment')
# (163, 'etc')
# (164, 'fee')
# (165, 'financial')
# (166, 'form')
# (167, 'friday')
# (168, 'grossly')
# (169, 'handle')
# (170, 'inform')
# (171, 'inside')
# (172, 'late')
# (173, 'left')
# (174, 'livelihood')
# (175, 'look')
# (176, 'may')
# (177, 'mind')
# (178, 'morgan')
# (179, 'notice')
# (180, 'occur')
# (181, 'owe')
# (182, 'past')
# (183, 'payment')
# (184, 'peace')
# (185, 'place')
# (186, 'post')
# (187, 'present')
# (188, 'professionally')
# (189, 'protocol')
# (190, 'realize')
# (191, 'recover')
# (192, 'rent')
# (193, 'reserve')
# (194, 'restrict')
# (195, 'retrieve')
# (196, 'return')
# (197, 'reversed')
# (198, 'saturday')
# (199, 'see')
# (200, 'seem')
# (201, 'shore')
# (202, 'short')
# (203, 'situation')
# (204, 'suspicious')
# (205, 'teller')
# (206, 'thank')
# (207, 'thing')
# (208, 'three')
# (209, 'thursday')
# (210, 'truly')
# (211, 'tuesday')
# (212, 'two')
# (213, 'unfortunately')
# (214, 'upon')
# (215, 'want')
# (216, 'well')
# (217, 'withdraw')
# (218, 'yet')
# (219, 'almost')
# (220, 'auto')
# (221, 'avail')
# (222, 'baffle')
# (223, 'base')
# (224, 'cfp')
# (225, 'communication')
# (226, 'company')
# (227, 'conference')
# (228, 'contractual')
# (229, 'decline')
# (230, 'delinquent')
# (231, 'denial')
# (232, 'department')
# (233, 'director')
# (234, 'discussion')
# (235, 'due')
# (236, 'emailed')
# (237, 'especially')
# (238, 'executive')
# (239, 'experience')
# (240, 'explanation')
# (241, 'explore')
# (242, 'extension')
# (243, 'follow')
# (244, 'four')
# (245, 'grant')
# (246, 'hand')
# (247, 'income')
# (248, 'informed')
# (249, 'jpmorgan')
# (250, 'lengthy')
# (251, 'letter')
# (252, 'like')
# (253, 'loan')
# (254, 'matter')
# (255, 'office')
# (256, 'one')
# (257, 'policy')
# (258, 'reason')
# (259, 'resolve')
# (260, 'review')
# (261, 'role')
# (262, 'share')
# (263, 'since')
# (264, 'stated')
# (265, 'still')
# (266, 'summer')
# (267, 'supervisor')
# (268, 'therefore')
# (269, 'wait')
# (270, 'week')
# (271, 'year')
# (272, 'absolve')
# (273, 'address')
# (274, 'admit')
# (275, 'advertise')
# (276, 'advertising')
# (277, 'already')
# (278, 'another')
# (279, 'app')
# (280, 'asked')
# (281, 'assist')
# (282, 'automate')
# (283, 'better')
# (284, 'closing')
# (285, 'complete')
# (286, 'confirmation')
# (287, 'dangerous')
# (288, 'deceive')
# (289, 'easy')
# (290, 'email')
# (291, 'end')
# (292, 'everything')
# (293, 'expertise')
# (294, 'fast')
# (295, 'feel')
# (296, 'felt')
# (297, 'finally')
# (298, 'find')
# (299, 'helpful')
# (300, 'informing')
# (301, 'initially')
# (302, 'initiate')
# (303, 'initiated')
# (304, 'inputted')
# (305, 'interrupt')
# (306, 'keep')
# (307, 'line')
# (308, 'list')
# (309, 'mention')
# (310, 'menu')
# (311, 'message')
# (312, 'nature')
# (313, 'navigate')
# (314, 'nothing')
# (315, 'online')
# (316, 'opportunity')
# (317, 'original')
# (318, 'outside')
# (319, 'perform')
# (320, 'phone')
# (321, 'phrase')
# (322, 'possible')
# (323, 'product')
# (324, 'provide')
# (325, 'question')
# (326, 'quick')
# (327, 'quickly')
# (328, 'recipient')
# (329, 'refund')
# (330, 'regard')
# (331, 'require')
# (332, 'response')
# (333, 'responsibility')
# (334, 'restate')
# (335, 'retailer')
# (336, 'reverse')
# (337, 'safe')
# (338, 'scam')
# (339, 'script')
# (340, 'second')
# (341, 'secure')
# (342, 'secured')
# (343, 'stay')
# (344, 'support')
# (345, 'system')
# (346, 'talk')
# (347, 'team')
# (348, 'technical')
# (349, 'transaction')
# (350, 'transfer')
# (351, 'transparent')
# (352, 'treat')
# (353, 'type')
# (354, 'understand')
# (355, 'understood')
# (356, 'used')
# (357, 'victimized')
# (358, 'way')
# (359, 'website')
# (360, 'whole')
# (361, 'word')
# (362, 'data')
# (363, 'incorrectly')
# (364, 'issue')
# (365, 'mishandle')
# (366, 'able')
# (367, 'action')
# (368, 'authorize')
# (369, 'bureau')
# (370, 'care')
# (371, 'creditor')
# (372, 'hold')
# (373, 'kind')
# (374, 'legal')
# (375, 'many')
# (376, 'nobody')
# (377, 'person')
# (378, 'quir')
# (379, 'reach')
# (380, 'several')
# (381, 'bonus')
# (382, 'code')
# (383, 'coupon')
# (384, 'term')
# (385, 'alert')
# (386, 'always')
# (387, 'anyway')
# (388, 'attach')
# (389, 'back')
# (390, 'balance')
# (391, 'cent')
# (392, 'charge')
# (393, 'concern')
# (394, 'cover')
# (395, 'fault')
# (396, 'guideline')
# (397, 'low')
# (398, 'medium')
# (399, 'overdraft')
# (400, 'overdraw')
# (401, 'people')
# (402, 'per')
# (403, 'sufi')
# (404, 'wrongly')
# (405, 'activate')
# (406, 'amazon')
# (407, 'amount')
# (408, 'answer')
# (409, 'around')
# (410, 'assurance')
# (411, 'brother')
# (412, 'cater')
# (413, 'confirm')
# (414, 'conversation')
# (415, 'either')
# (416, 'embarrassed')
# (417, 'figure')
# (418, 'frustrate')
# (419, 'full')
# (420, 'funeral')
# (421, 'hour')
# (422, 'initial')
# (423, 'input')
# (424, 'last')
# (425, 'limit')
# (426, 'mastercard')
# (427, 'monitor')
# (428, 'multiple')
# (429, 'noon')
# (430, 'rep')
# (431, 'respond')
# (432, 'restaurant')
# (433, 'saving')
# (434, 'set')
# (435, 'someone')
# (436, 'speak')
# (437, 'suggest')
# (438, 'sure')
# (439, 'text')
# (440, 'thought')
# (441, 'today')
# (442, 'told')
# (443, 'tonight')
# (444, 'trick')
# (445, 'user')
# (446, 'yes')
# (447, 'automatic')
# (448, 'cancel')
# (449, 'case')
# (450, 'consecutive')
# (451, 'enough')
# (452, 'fail')
# (453, 'reactivate')
# (454, 'save')
# (455, 'suppose')
# (456, 'chair')
# (457, 'deliver')
# (458, 'furniture')
# (459, 'love')
# (460, 'seat')
# (461, 'table')
# (462, 'visa')
# (463, 'miss')
# (464, 'afraid')
# (465, 'agree')
# (466, 'arbitration')
# (467, 'blatant')
# (468, 'clearly')
# (469, 'consequence')
# (470, 'contract')
# (471, 'despite')
# (472, 'dissuade')
# (473, 'egregiously')
# (474, 'enclose')
# (475, 'force')
# (476, 'important')
# (477, 'include')
# (478, 'loss')
# (479, 'malpractice')
# (480, 'massive')
# (481, 'method')
# (482, 'often')
# (483, 'opt')
# (484, 'part')
# (485, 'personal')
# (486, 'problem')
# (487, 'similar')
# (488, 'simply')
# (489, 'solely')
# (490, 'something')
# (491, 'title')
# (492, 'accuse')
# (493, 'activity')
# (494, 'also')
# (495, 'challenge')
# (496, 'character')
# (497, 'closure')
# (498, 'consider')
# (499, 'detrimental')
# (500, 'dispute')
# (501, 'duplicate')
# (502, 'escalation')
# (503, 'file')
# (504, 'filing')
# (505, 'final')
# (506, 'fraud')
# (507, 'involuntarily')
# (508, 'involuntary')
# (509, 'manager')
# (510, 'monday')
# (511, 'nevada')
# (512, 'provisional')
# (513, 'public')
# (514, 'reflect')
# (515, 'reporting')
# (516, 'seek')
# (517, 'shock')
# (518, 'slander')
# (519, 'sunday')
# (520, 'twice')
# (521, 'work')
# (522, 'access')
# (523, 'accord')
# (524, 'attention')
# (525, 'await')
# (526, 'complaint')
# (527, 'copy')
# (528, 'delete')
# (529, 'humbly')
# (530, 'inaccurate')
# (531, 'incomplete')
# (532, 'info')
# (533, 'match')
# (534, 'pertain')
# (535, 'recently')
# (536, 'rout')
# (537, 'show')
# (538, 'submitting')
# (539, 'true')
# (540, 'valid')
# (541, 'verifiable')
# (542, 'citizen')
# (543, 'ful')
# (544, 'scammed')
# (545, 'senior')
# (546, 'tried')
# (547, 'apologize')
# (548, 'atm')
# (549, 'drawl')
# (550, 'driver')
# (551, 'figured')
# (552, 'license')
# (553, 'password')
# (554, 'pin')
# (555, 'pretend')
# (556, 'protection')
# (557, 'prove')
# (558, 'room')
# (559, 'roommate')
# (560, 'sleep')
# (561, 'sneak')
# (562, 'spend')
# (563, 'steal')
# (564, 'wake')
# (565, 'behind')
# (566, 'doc')
# (567, 'let')
# (568, 'modification')
# (569, 'runaround')
# (570, 'apparently')
# (571, 'applied')
# (572, 'assistance')
# (573, 'attached')
# (574, 'deaf')
# (575, 'difference')
# (576, 'ear')
# (577, 'excess')
# (578, 'fell')
# (579, 'highest')
# (580, 'interest')
# (581, 'larger')
# (582, 'law')
# (583, 'logic')
# (584, 'meet')
# (585, 'minimum')
# (586, 'outstanding')
# (587, 'previous')
# (588, 'prior')
# (589, 'profit')
# (590, 'promotional')
# (591, 'rate')
# (592, 'rectify')
# (593, 'respectfully')
# (594, 'skirt')
# (595, 'turn')
# (596, 'understanding')
# (597, 'act')
# (598, 'ago')
# (599, 'anything')
# (600, 'appropriate')
# (601, 'become')
# (602, 'browser')
# (603, 'bunch')
# (604, 'buy')
# (605, 'center')
# (606, 'cold')
# (607, 'com')
# (608, 'computer')
# (609, 'deduct')
# (610, 'detail')
# (611, 'escalated')
# (612, 'eventually')
# (613, 'exchange')
# (614, 'fix')
# (615, 'flight')
# (616, 'freedom')
# (617, 'hotel')
# (618, 'huge')
# (619, 'image')
# (620, 'inconvenience')
# (621, 'intend')
# (622, 'least')
# (623, 'long')
# (624, 'lot')
# (625, 'neither')
# (626, 'operator')
# (627, 'page')
# (628, 'point')
# (629, 'relation')
# (630, 'result')
# (631, 'sapphire')
# (632, 'soon')
# (633, 'story')
# (634, 'tech')
# (635, 'temporary')
# (636, 'think')
# (637, 'travel')
# (638, 'ultimate')
# (639, 'unable')
# (640, 'uncommon')
# (641, 'worth')
# (642, 'accountable')
# (643, 'appear')
# (644, 'big')
# (645, 'brand')
# (646, 'careful')
# (647, 'comment')
# (648, 'community')
# (649, 'confusing')
# (650, 'continue')
# (651, 'deceptive')
# (652, 'educate')
# (653, 'encourage')
# (654, 'exempt')
# (655, 'expand')
# (656, 'false')
# (657, 'ignore')
# (658, 'incessant')
# (659, 'intentional')
# (660, 'lack')
# (661, 'lining')
# (662, 'machine')
# (663, 'market')
# (664, 'marketing')
# (665, 'middle')
# (666, 'mine')
# (667, 'new')
# (668, 'opaque')
# (669, 'plus')
# (670, 'practice')
# (671, 'previously')
# (672, 'reader')
# (673, 'relatively')
# (674, 'rule')
# (675, 'silver')
# (676, 'staff')
# (677, 'style')
# (678, 'trade')
# (679, 'train')
# (680, 'training')
# (681, 'triangle')
# (682, 'undisclosed')
# (683, 'waste')
# (684, 'acknowledge')
# (685, 'approval')
# (686, 'companion')
# (687, 'constitute')
# (688, 'definitely')
# (689, 'entire')
# (690, 'evidence')
# (691, 'feb')
# (692, 'link')
# (693, 'much')
# (694, 'pas')
# (695, 'promote')
# (696, 'promotion')
# (697, 'rapid')
# (698, 'sign')
# (699, 'specifically')
# (700, 'spending')
# (701, 'subsequent')
# (702, 'thus')
# (703, 'valuable')
# (704, 'verbally')
# (705, 'asset')
# (706, 'commit')
# (707, 'felony')
# (708, 'police')
# (709, 'security')
# (710, 'social')
# (711, 'assistant')
# (712, 'avoid')
# (713, 'bankruptcy')
# (714, 'bring')
# (715, 'chapter')
# (716, 'default')
# (717, 'exact')
# (718, 'family')
# (719, 'foreclosure')
# (720, 'harass')
# (721, 'honor')
# (722, 'mortgage')
# (723, 'payoff')
# (724, 'prepare')
# (725, 'proceeding')
# (726, 'property')
# (727, 'quality')
# (728, 'regulation')
# (729, 'reinstatement')
# (730, 'resident')
# (731, 'residential')
# (732, 'resort')
# (733, 'sale')
# (734, 'sense')
# (735, 'total')
# (736, 'trustee')
# (737, 'wire')
# (738, 'wrongful')
# (739, 'cancelled')
# (740, 'city')
# (741, 'directly')
# (742, 'mechanical')
# (743, 'night')
# (744, 'party')
# (745, 'private')
# (746, 'receiving')
# (747, 'reopen')
# (748, 'start')
# (749, 'thru')
# (750, 'tour')
# (751, 'transportation')
# (752, 'vendor')
# (753, 'move')
# (754, 'registration')
# (755, 'release')
# (756, 'resolution')
# (757, 'accrue')
# (758, 'additionally')
# (759, 'bill')
# (760, 'charging')
# (761, 'drop')
# (762, 'finish')
# (763, 'guy')
# (764, 'idea')
# (765, 'man')
# (766, 'mean')
# (767, 'mistake')
# (768, 'mobile')
# (769, 'negative')
# (770, 'represent')
# (771, 'score')
# (772, 'updated')
# (773, 'inquire')
# (774, 'unknown')
# (775, 'hurt')
# (776, 'numerous')
# (777, 'sell')
# (778, 'student')
# (779, 'works')
# (780, 'alternate')
# (781, 'attachment')
# (782, 'closed')
# (783, 'decide')
# (784, 'describe')
# (785, 'different')
# (786, 'disputed')
# (787, 'emphasize')
# (788, 'estimate')
# (789, 'ever')
# (790, 'exist')
# (791, 'five')
# (792, 'indicate')
# (793, 'item')
# (794, 'language')
# (795, 'locate')
# (796, 'merchant')
# (797, 'pre')
# (798, 'remain')
# (799, 'research')
# (800, 'screenshot')
# (801, 'shipment')
# (802, 'shipped')
# (803, 'significant')
# (804, 'willing')
# (805, 'banking')
# (806, 'freeze')
# (807, 'relationship')
# (808, 'responsible')
# (809, 'basically')
# (810, 'budge')
# (811, 'confusion')
# (812, 'continuously')
# (813, 'event')
# (814, 'excursion')
# (815, 'group')
# (816, 'history')
# (817, 'island')
# (818, 'itinerary')
# (819, 'large')
# (820, 'lead')
# (821, 'level')
# (822, 'lie')
# (823, 'partial')
# (824, 'pdf')
# (825, 'plan')
# (826, 'promise')
# (827, 'render')
# (828, 'side')
# (829, 'snorkel')
# (830, 'various')
# (831, 'accumulate')
# (832, 'accumulated')
# (833, 'acknowledgement')
# (834, 'acknowledgment')
# (835, 'advantage')
# (836, 'affiliate')
# (837, 'agency')
# (838, 'airline')
# (839, 'anyone')
# (840, 'anytime')
# (841, 'assign')
# (842, 'ate')
# (843, 'attitude')
# (844, 'attractive')
# (845, 'authority')
# (846, 'away')
# (847, 'basic')
# (848, 'behalf')
# (849, 'benefit')
# (850, 'beyond')
# (851, 'brief')
# (852, 'cancelation')
# (853, 'certificate')
# (854, 'circumstance')
# (855, 'condescend')
# (856, 'consultant')
# (857, 'correspond')
# (858, 'criterion')
# (859, 'death')
# (860, 'decease')
# (861, 'deep')
# (862, 'definitive')
# (863, 'delay')
# (864, 'deliberately')
# (865, 'design')
# (866, 'difficult')
# (867, 'disappointment')
# (868, 'disregard')
# (869, 'documentation')
# (870, 'dollar')
# (871, 'earlier')
# (872, 'excellent')
# (873, 'expect')
# (874, 'expectation')
# (875, 'expense')
# (876, 'express')
# (877, 'extreme')
# (878, 'extremely')
# (879, 'father')
# (880, 'federal')
# (881, 'flatly')
# (882, 'formal')
# (883, 'forum')
# (884, 'forward')
# (885, 'frustrating')
# (886, 'fulfill')
# (887, 'fulfilled')
# (888, 'great')
# (889, 'grief')
# (890, 'hear')
# (891, 'holder')
# (892, 'hop')
# (893, 'hope')
# (894, 'hopeful')
# (895, 'hundred')
# (896, 'husband')
# (897, 'impossible')
# (898, 'leave')
# (899, 'little')
# (900, 'main')
# (901, 'manage')
# (902, 'membership')
# (903, 'mismanagement')
# (904, 'necessary')
# (905, 'obligation')
# (906, 'offering')
# (907, 'offline')
# (908, 'ordeal')
# (909, 'organization')
# (910, 'outcome')
# (911, 'overseas')
# (912, 'pass')
# (913, 'poor')
# (914, 'premium')
# (915, 'probably')
# (916, 'proof')
# (917, 'quicker')
# (918, 'receipt')
# (919, 'recent')
# (920, 'reconsider')
# (921, 'reference')
# (922, 'regret')
# (923, 'regularly')
# (924, 'relate')
# (925, 'relevant')
# (926, 'repeatedly')
# (927, 'required')
# (928, 'respect')
# (929, 'respectful')
# (930, 'responsibly')
# (931, 'retuned')
# (932, 'scan')
# (933, 'shame')
# (934, 'sight')
# (935, 'slow')
# (936, 'standard')
# (937, 'stress')
# (938, 'stressful')
# (939, 'surprise')
# (940, 'third')
# (941, 'thousand')
# (942, 'till')
# (943, 'timely')
# (944, 'top')
# (945, 'translation')
# (946, 'trip')
# (947, 'united')
# (948, 'unresolved')
# (949, 'unresponsive')
# (950, 'upcoming')
# (951, 'update')
# (952, 'utilize')
# (953, 'utter')
# (954, 'voc')
# (955, 'wednesday')
# (956, 'yearly')
# (957, 'criminal')
# (958, 'draw')
# (959, 'drawn')
# (960, 'early')
# (961, 'increase')
# (962, 'insufficient')
# (963, 'might')
# (964, 'period')
# (965, 'theft')
# (966, 'excessive')
# (967, 'forbearance')
# (968, 'high')
# (969, 'mitigation')
# (970, 'option')
# (971, 'refinance')
# (972, 'amd')
# (973, 'inaccuracy')
# (974, 'involve')
# (975, 'none')
# (976, 'airport')
# (977, 'disappeared')
# (978, 'dropped')
# (979, 'pending')
# (980, 'usually')
# (981, 'weekend')
# (982, 'add')
# (983, 'advertisement')
# (984, 'automatically')
# (985, 'checking')
# (986, 'combine')
# (987, 'compensate')
# (988, 'correctly')
# (989, 'disclosure')
# (990, 'discus')
# (991, 'earn')
# (992, 'eligible')
# (993, 'employee')
# (994, 'enter')
# (995, 'frustrated')
# (996, 'furthermore')
# (997, 'investigate')
# (998, 'lady')
# (999, 'local')
# (1000, 'maintain')
# (1001, 'management')
# (1002, 'read')
# (1003, 'recall')
# (1004, 'regardless')
# (1005, 'rightfully')
# (1006, 'source')
# (1007, 'step')
# (1008, 'subject')
# (1009, 'upset')
# (1010, 'advised')
# (1011, 'billing')
# (1012, 'eat')
# (1013, 'ignored')
# (1014, 'institution')
# (1015, 'must')
# (1016, 'notify')
# (1017, 'reg')
# (1018, 'bounce')
# (1019, 'class')
# (1020, 'draft')
# (1021, 'eastern')
# (1022, 'latest')
# (1023, 'lawsuit')
# (1024, 'manipulate')
# (1025, 'maximize')
# (1026, 'next')
# (1027, 'organize')
# (1028, 'positive')
# (1029, 'shot')
# (1030, 'stuff')
# (1031, 'accident')
# (1032, 'addendum')
# (1033, 'agreement')
# (1034, 'commitment')
# (1035, 'coverage')
# (1036, 'deficiency')
# (1037, 'drive')
# (1038, 'finance')
# (1039, 'financing')
# (1040, 'gap')
# (1041, 'insurance')
# (1042, 'lien')
# (1043, 'military')
# (1044, 'provider')
# (1045, 'provision')
# (1046, 'purchased')
# (1047, 'salvage')
# (1048, 'ship')
# (1049, 'station')
# (1050, 'value')
# (1051, 'vehicle')
# (1052, 'waive')
# (1053, 'waiver')
# (1054, 'fully')
# (1055, 'prepared')
# (1056, 'sue')
# (1057, 'totally')
# (1058, 'accounting')
# (1059, 'bad')
# (1060, 'birth')
# (1061, 'booking')
# (1062, 'carefully')
# (1063, 'connect')
# (1064, 'demand')
# (1065, 'destination')
# (1066, 'diligence')
# (1067, 'fly')
# (1068, 'head')
# (1069, 'horrible')
# (1070, 'inability')
# (1071, 'incident')
# (1072, 'investigation')
# (1073, 'job')
# (1074, 'laptop')
# (1075, 'old')
# (1076, 'pretty')
# (1077, 'proper')
# (1078, 'whenever')
# (1079, 'actual')
# (1080, 'actuality')
# (1081, 'adequate')
# (1082, 'airfare')
# (1083, 'altogether')
# (1084, 'anymore')
# (1085, 'begin')
# (1086, 'cancellation')
# (1087, 'carrier')
# (1088, 'catch')
# (1089, 'cause')
# (1090, 'connection')
# (1091, 'contention')
# (1092, 'damage')
# (1093, 'difficulty')
# (1094, 'discount')
# (1095, 'double')
# (1096, 'empower')
# (1097, 'entitle')
# (1098, 'equate')
# (1099, 'essentially')
# (1100, 'euros')
# (1101, 'fall')
# (1102, 'fare')
# (1103, 'financially')
# (1104, 'flown')
# (1105, 'food')
# (1106, 'friendly')
# (1107, 'grateful')
# (1108, 'home')
# (1109, 'incur')
# (1110, 'individual')
# (1111, 'liability')
# (1112, 'liable')
# (1113, 'likely')
# (1114, 'literally')
# (1115, 'lodge')
# (1116, 'non')
# (1117, 'obviously')
# (1118, 'origin')
# (1119, 'originally')
# (1120, 'pair')
# (1121, 'pant')
# (1122, 'parent')
# (1123, 'partially')
# (1124, 'passenger')
# (1125, 'position')
# (1126, 'reschedule')
# (1127, 'roof')
# (1128, 'round')
# (1129, 'serious')
# (1130, 'shingle')
# (1131, 'shirt')
# (1132, 'simple')
# (1133, 'six')
# (1134, 'sorry')
# (1135, 'strain')
# (1136, 'teacher')
# (1137, 'tear')
# (1138, 'throughout')
# (1139, 'unexpected')
# (1140, 'world')
# (1141, 'worse')
# (1142, 'worthless')
# (1143, 'wow')
# (1144, 'join')
# (1145, 'age')
# (1146, 'banker')
# (1147, 'cash')
# (1148, 'discriminate')
# (1149, 'fine')
# (1150, 'indeed')
# (1151, 'lock')
# (1152, 'received')
# (1153, 'size')
# (1154, 'ultimately')
# (1155, 'whatever')
# (1156, 'create')
# (1157, 'internet')
# (1158, 'knowing')
# (1159, 'life')
# (1160, 'paper')
# (1161, 'rest')
# (1162, 'club')
# (1163, 'discuss')
# (1164, 'lose')
# (1165, 'siding')
# (1166, 'stayed')
# (1167, 'strip')
# (1168, 'sum')
# (1169, 'venue')
# (1170, 'civil')
# (1171, 'comply')
# (1172, 'court')
# (1173, 'enforce')
# (1174, 'litigation')
# (1175, 'litigious')
# (1176, 'mark')
# (1177, 'monthly')
# (1178, 'pursue')
# (1179, 'remedy')
# (1180, 'sick')
# (1181, 'threat')
# (1182, 'violation')
# (1183, 'advice')
# (1184, 'authorized')
# (1185, 'badger')
# (1186, 'bit')
# (1187, 'course')
# (1188, 'description')
# (1189, 'dismiss')
# (1190, 'dues')
# (1191, 'escalate')
# (1192, 'handful')
# (1193, 'hung')
# (1194, 'kept')
# (1195, 'known')
# (1196, 'mid')
# (1197, 'odd')
# (1198, 'paperwork')
# (1199, 'personally')
# (1200, 'phishing')
# (1201, 'potential')
# (1202, 'retroactively')
# (1203, 'roughly')
# (1204, 'rude')
# (1205, 'saw')
# (1206, 'school')
# (1207, 'specialist')
# (1208, 'subpoena')
# (1209, 'unauthorized')
# (1210, 'voice')
# (1211, 'iam')
# (1212, 'permission')
# (1213, 'setup')
# (1214, 'afternoon')
# (1215, 'anywhere')
# (1216, 'breach')
# (1217, 'hard')
# (1218, 'hello')
# (1219, 'imagine')
# (1220, 'indication')
# (1221, 'okay')
# (1222, 'particularly')
# (1223, 'pull')
# (1224, 'subscribe')
# (1225, 'understandably')
# (1226, 'actively')
# (1227, 'alas')
# (1228, 'approximately')
# (1229, 'associated')
# (1230, 'deadline')
# (1231, 'deserve')
# (1232, 'entity')
# (1233, 'government')
# (1234, 'ink')
# (1235, 'liquidated')
# (1236, 'missed')
# (1237, 'others')
# (1238, 'own')
# (1239, 'potentially')
# (1240, 'pro')
# (1241, 'program')
# (1242, 'site')
# (1243, 'uda')
# (1244, 'yesterday')
# (1245, 'really')
# (1246, 'solve')
# (1247, 'successfully')
# (1248, 'unacceptable')
# (1249, 'appeal')
# (1250, 'recognize')
# (1251, 'crash')
# (1252, 'illinois')
# (1253, 'insert')
# (1254, 'trouble')
# (1255, 'acquiesce')
# (1256, 'aggravate')
# (1257, 'apart')
# (1258, 'assume')
# (1259, 'basis')
# (1260, 'cost')
# (1261, 'delayed')
# (1262, 'endorse')
# (1263, 'endorsement')
# (1264, 'far')
# (1265, 'firm')
# (1266, 'improper')
# (1267, 'improperly')
# (1268, 'ing')
# (1269, 'landlord')
# (1270, 'national')
# (1271, 'obligated')
# (1272, 'payable')
# (1273, 'payee')
# (1274, 'profitability')
# (1275, 'promptly')
# (1276, 'properly')
# (1277, 'recommend')
# (1278, 'reduce')
# (1279, 'resubmitted')
# (1280, 'risk')
# (1281, 'spite')
# (1282, 'telephone')
# (1283, 'ucc')
# (1284, 'variant')
# (1285, 'award')
# (1286, 'client')
# (1287, 'combined')
# (1288, 'compassion')
# (1289, 'economic')
# (1290, 'free')
# (1291, 'opening')
# (1292, 'portion')
# (1293, 'practically')
# (1294, 'print')
# (1295, 'qualify')
# (1296, 'solicitation')
# (1297, 'superior')
# (1298, 'archive')
# (1299, 'conceal')
# (1300, 'older')
# (1301, 'operate')
# (1302, 'purpose')
# (1303, 'statute')
# (1304, 'success')
# (1305, 'toll')
# (1306, 'allow')
# (1307, 'cleaned')
# (1308, 'discover')
# (1309, 'expedite')
# (1310, 'unethical')
# (1311, 'asleep')
# (1312, 'brought')
# (1313, 'cell')
# (1314, 'footage')
# (1315, 'impression')
# (1316, 'mile')
# (1317, 'possibility')
# (1318, 'reimburse')
# (1319, 'reimbursement')
# (1320, 'video')
# (1321, 'withdrawal')
# (1322, 'worry')
# (1323, 'afterwards')
# (1324, 'complain')
# (1325, 'courtesy')
# (1326, 'hit')
# (1327, 'house')
# (1328, 'largest')
# (1329, 'occasion')
# (1330, 'opinion')
# (1331, 'payday')
# (1332, 'run')
# (1333, 'shady')
# (1334, 'smaller')
# (1335, 'struggle')
# (1336, 'subsequently')
# (1337, 'accordingly')
# (1338, 'kindly')
# (1339, 'secondly')
# (1340, 'adjust')
# (1341, 'erroneous')
# (1342, 'escrow')
# (1343, 'footing')
# (1344, 'immediate')
# (1345, 'incorrect')
# (1346, 'knowledge')
# (1347, 'misappropriate')
# (1348, 'municipality')
# (1349, 'parcel')
# (1350, 'perspective')
# (1351, 'shortage')
# (1352, 'stuck')
# (1353, 'tax')
# (1354, 'atleast')
# (1355, 'cart')
# (1356, 'midnight')
# (1357, 'alone')
# (1358, 'belong')
# (1359, 'expose')
# (1360, 'prompt')
# (1361, 'whose')
# (1362, 'else')
# (1363, 'exhibit')
# (1364, 'nonrefundable')
# (1365, 'plane')
# (1366, 'unless')
# (1367, 'colorado')
# (1368, 'electronic')
# (1369, 'extra')
# (1370, 'forget')
# (1371, 'froze')
# (1372, 'partner')
# (1373, 'sender')
# (1374, 'unfair')
# (1375, 'forth')
# (1376, 'hardship')
# (1377, 'lower')
# (1378, 'ludicrous')
# (1379, 'note')
# (1380, 'discovery')
# (1381, 'enquire')
# (1382, 'hence')
# (1383, 'investigated')
# (1384, 'mutual')
# (1385, 'nsf')
# (1386, 'originated')
# (1387, 'seller')
# (1388, 'sincerely')
# (1389, 'solution')
# (1390, 'sufficient')
# (1391, 'usd')
# (1392, 'circle')
# (1393, 'fashion')
# (1394, 'feeling')
# (1395, 'hid')
# (1396, 'listing')
# (1397, 'normal')
# (1398, 'terrible')
# (1399, 'ach')
# (1400, 'closely')
# (1401, 'confuse')
# (1402, 'dozen')
# (1403, 'ideally')
# (1404, 'luck')
# (1405, 'originate')
# (1406, 'ought')
# (1407, 'reported')
# (1408, 'span')
# (1409, 'ups')
# (1410, 'accept')
# (1411, 'addition')
# (1412, 'affair')
# (1413, 'argumentative')
# (1414, 'attorney')
# (1415, 'bookkeeper')
# (1416, 'box')
# (1417, 'checkbook')
# (1418, 'claimed')
# (1419, 'collection')
# (1420, 'commercial')
# (1421, 'concerned')
# (1422, 'corporate')
# (1423, 'correspondence')
# (1424, 'covered')
# (1425, 'declare')
# (1426, 'delaware')
# (1427, 'equipment')
# (1428, 'extent')
# (1429, 'foreign')
# (1430, 'forgive')
# (1431, 'forgiven')
# (1432, 'forgiveness')
# (1433, 'forgot')
# (1434, 'frozen')
# (1435, 'genuinely')
# (1436, 'guarantor')
# (1437, 'guide')
# (1438, 'heard')
# (1439, 'hire')
# (1440, 'importantly')
# (1441, 'inactive')
# (1442, 'incorporate')
# (1443, 'infrastructure')
# (1444, 'insolvency')
# (1445, 'instance')
# (1446, 'interact')
# (1447, 'irs')
# (1448, 'keeper')
# (1449, 'knew')
# (1450, 'lawyer')
# (1451, 'location')
# (1452, 'major')
# (1453, 'names')
# (1454, 'official')
# (1455, 'oftentimes')
# (1456, 'ongoing')
# (1457, 'outline')
# (1458, 'perhaps')
# (1459, 'physical')
# (1460, 'possession')
# (1461, 'produce')
# (1462, 'production')
# (1463, 'promised')
# (1464, 'propose')
# (1465, 'protected')
# (1466, 'raise')
# (1467, 'rather')
# (1468, 'referencing')
# (1469, 'regular')
# (1470, 'reiterate')
# (1471, 'representation')
# (1472, 'section')
# (1473, 'self')
# (1474, 'sent')
# (1475, 'separate')
# (1476, 'showing')
# (1477, 'signatory')
# (1478, 'signature')
# (1479, 'small')
# (1480, 'sole')
# (1481, 'specific')
# (1482, 'stance')
# (1483, 'status')
# (1484, 'summation')
# (1485, 'supply')
# (1486, 'touch')
# (1487, 'walk')
# (1488, 'approximate')
# (1489, 'arbitrary')
# (1490, 'automotive')
# (1491, 'awful')
# (1492, 'bully')
# (1493, 'burden')
# (1494, 'callous')
# (1495, 'common')
# (1496, 'corporation')
# (1497, 'cruel')
# (1498, 'effort')
# (1499, 'greedy')
# (1500, 'illegal')
# (1501, 'inexcusable')
# (1502, 'intent')
# (1503, 'justice')
# (1504, 'malicious')
# (1505, 'model')
# (1506, 'news')
# (1507, 'preferred')
# (1508, 'reckless')
# (1509, 'repair')
# (1510, 'respectively')
# (1511, 'severely')
# (1512, 'slash')
# (1513, 'spirit')
# (1514, 'undue')
# (1515, 'unforeseen')
# (1516, 'unjustified')
# (1517, 'unlimited')
# (1518, 'veteran')
# (1519, 'accessible')
# (1520, 'aforementioned')
# (1521, 'amicably')
# (1522, 'checkout')
# (1523, 'completely')
# (1524, 'credential')
# (1525, 'device')
# (1526, 'equally')
# (1527, 'fri')
# (1528, 'intervene')
# (1529, 'licence')
# (1530, 'login')
# (1531, 'mediate')
# (1532, 'mon')
# (1533, 'nark')
# (1534, 'planing')
# (1535, 'prefer')
# (1536, 'search')
# (1537, 'series')
# (1538, 'smug')
# (1539, 'unhelpful')
# (1540, 'verified')
# (1541, 'visit')
# (1542, 'electric')
# (1543, 'overdrew')
# (1544, 'related')
# (1545, 'waived')
# (1546, 'aggressive')
# (1547, 'bos')
# (1548, 'checked')
# (1549, 'formerly')
# (1550, 'learn')
# (1551, 'provided')
# (1552, 'repeated')
# (1553, 'battle')
# (1554, 'breakdown')
# (1555, 'daughter')
# (1556, 'devastated')
# (1557, 'discretion')
# (1558, 'durable')
# (1559, 'hearing')
# (1560, 'hospital')
# (1561, 'human')
# (1562, 'insensitive')
# (1563, 'nervous')
# (1564, 'oldest')
# (1565, 'power')
# (1566, 'purposely')
# (1567, 'arguable')
# (1568, 'arrive')
# (1569, 'callback')
# (1570, 'compliance')
# (1571, 'concrete')
# (1572, 'cosigner')
# (1573, 'dept')
# (1574, 'existent')
# (1575, 'greet')
# (1576, 'grievance')
# (1577, 'internal')
# (1578, 'misinformation')
# (1579, 'piece')
# (1580, 'receives')
# (1581, 'recovery')
# (1582, 'repayment')
# (1583, 'requested')
# (1584, 'retire')
# (1585, 'scrap')
# (1586, 'single')
# (1587, 'tangible')
# (1588, 'woman')
# (1589, 'advertised')
# (1590, 'elapse')
# (1591, 'sound')
# (1592, 'widely')
# (1593, 'blame')
# (1594, 'instruction')
# (1595, 'recourse')
# (1596, 'register')
# (1597, 'successful')
# (1598, 'afford')
# (1599, 'artist')
# (1600, 'aware')
# (1601, 'choose')
# (1602, 'illusion')
# (1603, 'pier')
# (1604, 'portal')
# (1605, 'rental')
# (1606, 'together')
# (1607, 'tool')
# (1608, 'upfront')
# (1609, 'bankrupt')
# (1610, 'errant')
# (1611, 'evidently')
# (1612, 'evil')
# (1613, 'field')
# (1614, 'manual')
# (1615, 'negligent')
# (1616, 'pain')
# (1617, 'restart')
# (1618, 'terminate')
# (1619, 'block')
# (1620, 'hack')
# (1621, 'regain')
# (1622, 'accurate')
# (1623, 'happy')
# (1624, 'measure')
# (1625, 'protect')
# (1626, 'reappear')
# (1627, 'refrain')
# (1628, 'usage')
# (1629, 'bottom')
# (1630, 'empathetic')
# (1631, 'flaw')
# (1632, 'ineffective')
# (1633, 'issued')
# (1634, 'quite')
# (1635, 'rob')
# (1636, 'somehow')
# (1637, 'stole')
# (1638, 'texas')
# (1639, 'thief')
# (1640, 'travesty')
# (1641, 'union')
# (1642, 'unsafe')
# (1643, 'wash')
# (1644, 'weak')
# (1645, 'active')
# (1646, 'bait')
# (1647, 'classic')
# (1648, 'click')
# (1649, 'cooky')
# (1650, 'cut')
# (1651, 'discontinue')
# (1652, 'eliminate')
# (1653, 'expiration')
# (1654, 'fill')
# (1655, 'legitimate')
# (1656, 'rake')
# (1657, 'reign')
# (1658, 'requirement')
# (1659, 'reviewer')
# (1660, 'sometime')
# (1661, 'spent')
# (1662, 'switch')
# (1663, 'unaware')
# (1664, 'web')
# (1665, 'din')
# (1666, 'lunch')
# (1667, 'park')
# (1668, 'purposeful')
# (1669, 'utility')
# (1670, 'approved')
# (1671, 'deprive')
# (1672, 'earned')
# (1673, 'referee')
# (1674, 'referral')
# (1675, 'briefly')
# (1676, 'communicate')
# (1677, 'dealt')
# (1678, 'door')
# (1679, 'environment')
# (1680, 'failure')
# (1681, 'importance')
# (1682, 'joke')
# (1683, 'ment')
# (1684, 'mess')
# (1685, 'outgo')
# (1686, 'sage')
# (1687, 'sneaky')
# (1688, 'tactic')
# (1689, 'watch')
# (1690, 'wish')
# (1691, 'activated')
# (1692, 'bearing')
# (1693, 'boiler')
# (1694, 'chance')
# (1695, 'clarity')
# (1696, 'derogatory')
# (1697, 'determine')
# (1698, 'dig')
# (1699, 'disclose')
# (1700, 'effective')
# (1701, 'electronically')
# (1702, 'elude')
# (1703, 'english')
# (1704, 'exp')
# (1705, 'ext')
# (1706, 'fair')
# (1707, 'folk')
# (1708, 'generic')
# (1709, 'gov')
# (1710, 'http')
# (1711, 'identical')
# (1712, 'influence')
# (1713, 'invite')
# (1714, 'locked')
# (1715, 'mls')
# (1716, 'officially')
# (1717, 'ohio')
# (1718, 'plate')
# (1719, 'possibly')
# (1720, 'preference')
# (1721, 'president')
# (1722, 'press')
# (1723, 'pressed')
# (1724, 'prevention')
# (1725, 'printed')
# (1726, 'printout')
# (1727, 'privacy')
# (1728, 'reinstate')
# (1729, 'resource')
# (1730, 'sit')
# (1731, 'slip')
# (1732, 'specialized')
# (1733, 'stub')
# (1734, 'timeline')
# (1735, 'unlikely')
# (1736, 'validation')
# (1737, 'vice')
# (1738, 'yield')
# (1739, 'noncompliance')
# (1740, 'booked')
# (1741, 'depart')
# (1742, 'disprove')
# (1743, 'easily')
# (1744, 'evening')
# (1745, 'feature')
# (1746, 'frustration')
# (1747, 'pertinent')
# (1748, 'proven')
# (1749, 'repeat')
# (1750, 'semi')
# (1751, 'twenty')
# (1752, 'absurd')
# (1753, 'busy')
# (1754, 'cashier')
# (1755, 'competency')
# (1756, 'contemplate')
# (1757, 'coworker')
# (1758, 'declaration')
# (1759, 'destroy')
# (1760, 'nearly')
# (1761, 'notarize')
# (1762, 'overnight')
# (1763, 'physically')
# (1764, 'refused')
# (1765, 'relent')
# (1766, 'schedule')
# (1767, 'seven')
# (1768, 'store')
# (1769, 'virginia')
# (1770, 'configure')
# (1771, 'control')
# (1772, 'demonstrate')
# (1773, 'fairly')
# (1774, 'guilty')
# (1775, 'harassment')
# (1776, 'incompetence')
# (1777, 'joint')
# (1778, 'profile')
# (1779, 'refers')
# (1780, 'silence')
# (1781, 'trust')
# (1782, 'wife')
# (1783, 'accidentally')
# (1784, 'mob')
# (1785, 'reply')
# (1786, 'uncertain')
# (1787, 'clarify')
# (1788, 'conversion')
# (1789, 'noticed')
# (1790, 'host')
# (1791, 'hosting')
# (1792, 'incompetent')
# (1793, 'kes')
# (1794, 'land')
# (1795, 'project')
# (1796, 'returned')
# (1797, 'shortly')
# (1798, 'supervision')
# (1799, 'adhere')
# (1800, 'auction')
# (1801, 'buyer')
# (1802, 'condition')
# (1803, 'consideration')
# (1804, 'district')
# (1805, 'estate')
# (1806, 'homeowner')
# (1807, 'liens')
# (1808, 'neglect')
# (1809, 'negligence')
# (1810, 'proceeds')
# (1811, 'real')
# (1812, 'addressed')
# (1813, 'confirmed')
# (1814, 'cycle')
# (1815, 'dated')
# (1816, 'decrease')
# (1817, 'display')
# (1818, 'ensure')
# (1819, 'extensively')
# (1820, 'face')
# (1821, 'fax')
# (1822, 'feasible')
# (1823, 'future')
# (1824, 'gain')
# (1825, 'highlight')
# (1826, 'impact')
# (1827, 'issuer')
# (1828, 'lender')
# (1829, 'live')
# (1830, 'log')
# (1831, 'lure')
# (1832, 'malfunction')
# (1833, 'needed')
# (1834, 'notation')
# (1835, 'outdated')
# (1836, 'populate')
# (1837, 'prevent')
# (1838, 'rating')
# (1839, 'reassured')
# (1840, 'restore')
# (1841, 'reversal')
# (1842, 'uncover')
# (1843, 'unit')
# (1844, 'updating')
# (1845, 'view')
# (1846, 'guess')
# (1847, 'qualification')
# (1848, 'ride')
# (1849, 'snap')
# (1850, 'snapshots')
# (1851, 'expire')
# (1852, 'ruin')
# (1853, 'sends')
# (1854, 'utilization')
# (1855, 'abuse')
# (1856, 'apps')
# (1857, 'ass')
# (1858, 'assess')
# (1859, 'child')
# (1860, 'count')
# (1861, 'laugh')
# (1862, 'manger')
# (1863, 'otherwise')
# (1864, 'affidavit')
# (1865, 'altered')
# (1866, 'county')
# (1867, 'denied')
# (1868, 'faxed')
# (1869, 'frame')
# (1870, 'insist')
# (1871, 'precinct')
# (1872, 'blocked')
# (1873, 'ridiculous')
# (1874, 'treatment')
# (1875, 'argument')
# (1876, 'belief')
# (1877, 'boundary')
# (1878, 'commerce')
# (1879, 'deem')
# (1880, 'faulty')
# (1881, 'former')
# (1882, 'guarantee')
# (1883, 'heavily')
# (1884, 'higher')
# (1885, 'involved')
# (1886, 'module')
# (1887, 'mother')
# (1888, 'overall')
# (1889, 'overstep')
# (1890, 'perplex')
# (1891, 'precious')
# (1892, 'refusal')
# (1893, 'relative')
# (1894, 'removed')
# (1895, 'startup')
# (1896, 'unreasonable')
# (1897, 'unrelated')
# (1898, 'unusual')
# (1899, 'victim')
# (1900, 'essence')
# (1901, 'spanish')
# (1902, 'familiar')
# (1903, 'inappropriately')
# (1904, 'lucky')
# (1905, 'normally')
# (1906, 'pattern')
# (1907, 'tie')
# (1908, 'unsuspecting')
# (1909, 'wonder')
# (1910, 'amend')
# (1911, 'attend')
# (1912, 'compare')
# (1913, 'lease')
# (1914, 'mileage')
# (1915, 'remediate')
# (1916, 'stand')
# (1917, 'stipulate')
# (1918, 'threatened')
# (1919, 'wear')
# (1920, 'writing')
# (1921, 'arrangement')
# (1922, 'arras')
# (1923, 'disability')
# (1924, 'fed')
# (1925, 'nonstop')
# (1926, 'tod')
# (1927, 'rize')
# (1928, 'roi')
# (1929, 'zed')
# (1930, 'admittedly')
# (1931, 'apartment')
# (1932, 'badge')
# (1933, 'best')
# (1934, 'central')
# (1935, 'coworkers')
# (1936, 'division')
# (1937, 'emails')
# (1938, 'entitled')
# (1939, 'exception')
# (1940, 'gated')
# (1941, 'incentive')
# (1942, 'indiana')
# (1943, 'replace')
# (1944, 'stolen')
# (1945, 'summarize')
# (1946, 'wallet')
# (1947, 'wisconsin')
# (1948, 'withdrew')
# (1949, 'apology')
# (1950, 'borrow')
# (1951, 'break')
# (1952, 'cellphone')
# (1953, 'consular')
# (1954, 'crime')
# (1955, 'disappointed')
# (1956, 'electricity')
# (1957, 'friends')
# (1958, 'gas')
# (1959, 'intimidate')
# (1960, 'las')
# (1961, 'mailing')
# (1962, 'mers')
# (1963, 'nightmare')
# (1964, 'passport')
# (1965, 'pennsylvania')
# (1966, 'professional')
# (1967, 'sometimes')
# (1968, 'whoever')
# (1969, 'york')
# (1970, 'conclusion')
# (1971, 'contest')
# (1972, 'evaluate')
# (1973, 'exercise')
# (1974, 'reside')
# (1975, 'screenshots')
# (1976, 'technology')
# (1977, 'afterward')
# (1978, 'approach')
# (1979, 'baffled')
# (1980, 'clerk')
# (1981, 'deducted')
# (1982, 'dispense')
# (1983, 'lastly')
# (1984, 'longtime')
# (1985, 'noise')
# (1986, 'pdt')
# (1987, 'proceeded')
# (1988, 'ready')
# (1989, 'terminal')
# (1990, 'void')
# (1991, 'along')
# (1992, 'anybody')
# (1993, 'association')
# (1994, 'biggest')
# (1995, 'friend')
# (1996, 'revert')
# (1997, 'scenario')
# (1998, 'abusive')
# (1999, 'accommodation')
# (2000, 'acquaintance')
# (2001, 'advisor')
# (2002, 'affirmation')
# (2003, 'affords')
# (2004, 'aggrieve')
# (2005, 'allegation')
# (2006, 'alter')
# (2007, 'amendment')
# (2008, 'apparent')
# (2009, 'appraisal')
# (2010, 'appraise')
# (2011, 'apr')
# (2012, 'arise')
# (2013, 'arrival')
# (2014, 'articulate')
# (2015, 'assertion')
# (2016, 'automated')
# (2017, 'behavior')
# (2018, 'bless')
# (2019, 'borrower')
# (2020, 'bound')
# (2021, 'broker')
# (2022, 'building')
# (2023, 'buying')
# (2024, 'calculation')
# (2025, 'calculator')
# (2026, 'california')
# (2027, 'candor')
# (2028, 'category')
# (2029, 'ccp')
# (2030, 'certain')
# (2031, 'civ')
# (2032, 'clarifies')
# (2033, 'clock')
# (2034, 'columbia')
# (2035, 'competitor')
# (2036, 'concurrently')
# (2037, 'conduct')
# (2038, 'conspicuous')
# (2039, 'constitution')
# (2040, 'construct')
# (2041, 'construction')
# (2042, 'contemporaneous')
# (2043, 'context')
# (2044, 'contravention')
# (2045, 'counter')
# (2046, 'creation')
# (2047, 'deceit')
# (2048, 'deception')
# (2049, 'define')
# (2050, 'definition')
# (2051, 'desktop')
# (2052, 'disclaimer')
# (2053, 'disclosures')
# (2054, 'discrepancy')
# (2055, 'discrimination')
# (2056, 'discriminatory')
# (2057, 'disdain')
# (2058, 'disperse')
# (2059, 'distinguish')
# (2060, 'doubt')
# (2061, 'dubious')
# (2062, 'duty')
# (2063, 'dwell')
# (2064, 'edt')
# (2065, 'eight')
# (2066, 'enact')
# (2067, 'engage')
# (2068, 'enumerate')
# (2069, 'equity')
# (2070, 'evade')
# (2071, 'exclude')
# (2072, 'exclusive')
# (2073, 'exemption')
# (2074, 'expeditiously')
# (2075, 'facility')
# (2076, 'faith')
# (2077, 'fico')
# (2078, 'forwarding')
# (2079, 'found')
# (2080, 'fourteen')
# (2081, 'general')
# (2082, 'generation')
# (2083, 'ground')
# (2084, 'hang')
# (2085, 'hanging')
# (2086, 'housing')
# (2087, 'impose')
# (2088, 'improve')
# (2089, 'induce')
# (2090, 'inference')
# (2091, 'inferior')
# (2092, 'injure')
# (2093, 'injured')
# (2094, 'injury')
# (2095, 'institutional')
# (2096, 'instruct')
# (2097, 'intended')
# (2098, 'intention')
# (2099, 'interpret')
# (2100, 'interpretation')
# (2101, 'intimate')
# (2102, 'introduce')
# (2103, 'invoke')
# (2104, 'ion')
# (2105, 'itemize')
# (2106, 'junk')
# (2107, 'knowledgeable')
# (2108, 'lending')
# (2109, 'load')
# (2110, 'lowest')
# (2111, 'manner')
# (2112, 'meaning')
# (2113, 'meeting')
# (2114, 'merely')
# (2115, 'misleading')
# (2116, 'mrs')
# (2117, 'narrative')
# (2118, 'nary')
# (2119, 'nice')
# (2120, 'occupancy')
# (2121, 'occupied')
# (2122, 'occupy')
# (2123, 'operation')
# (2124, 'ordinary')
# (2125, 'ownership')
# (2126, 'performing')
# (2127, 'plain')
# (2128, 'pocket')
# (2129, 'predicate')
# (2130, 'preliminary')
# (2131, 'presented')
# (2132, 'prevail')
# (2133, 'price')
# (2134, 'pricing')
# (2135, 'principle')
# (2136, 'privilege')
# (2137, 'procedure')
# (2138, 'prohibit')
# (2139, 'prohibition')
# (2140, 'prospective')
# (2141, 'purchasing')
# (2142, 'quote')
# (2143, 'range')
# (2144, 'reasonable')
# (2145, 'refinancing')
# (2146, 'remainder')
# (2147, 'remit')
# (2148, 'represented')
# (2149, 'residence')
# (2150, 'revise')
# (2151, 'satisfied')
# (2152, 'satisfy')
# (2153, 'sec')
# (2154, 'secret')
# (2155, 'selection')
# (2156, 'selling')
# (2157, 'shall')
# (2158, 'spam')
# (2159, 'specify')
# (2160, 'starter')
# (2161, 'stats')
# (2162, 'strengthen')
# (2163, 'structure')
# (2164, 'sub')
# (2165, 'subdivision')
# (2166, 'subsection')
# (2167, 'suffers')
# (2168, 'suggestion')
# (2169, 'suit')
# (2170, 'suppression')
# (2171, 'task')
# (2172, 'tenure')
# (2173, 'tle')
# (2174, 'trusted')
# (2175, 'unlawful')
# (2176, 'urgent')
# (2177, 'vacant')
# (2178, 'vail')
# (2179, 'voter')
# (2180, 'whether')
# (2181, 'willfully')
# (2182, 'wrap')
# (2183, 'exactly')
# (2184, 'longest')
# (2185, 'penalize')
# (2186, 'processed')
# (2187, 'processing')
# (2188, 'standing')
# (2189, 'whatsoever')
# (2190, 'couple')
# (2191, 'everyday')
# (2192, 'loyal')
# (2193, 'board')
# (2194, 'cautious')
# (2195, 'ceo')
# (2196, 'compensation')
# (2197, 'except')
# (2198, 'firstly')
# (2199, 'nearest')
# (2200, 'paycheck')
# (2201, 'reliable')
# (2202, 'unsatisfactory')
# (2203, 'currency')
# (2204, 'forcibly')
# (2205, 'moreover')
# (2206, 'permissible')
# (2207, 'validated')
# (2208, 'char')
# (2209, 'disrespect')
# (2210, 'length')
# (2211, 'remember')
# (2212, 'black')
# (2213, 'american')
# (2214, 'discharge')
# (2215, 'doctor')
# (2216, 'education')
# (2217, 'examine')
# (2218, 'explained')
# (2219, 'half')
# (2220, 'ham')
# (2221, 'judge')
# (2222, 'medical')
# (2223, 'permanently')
# (2224, 'primarily')
# (2225, 'primary')
# (2226, 'water')
# (2227, 'ability')
# (2228, 'akin')
# (2229, 'bush')
# (2230, 'certainly')
# (2231, 'convenience')
# (2232, 'discern')
# (2233, 'flag')
# (2234, 'mistakenly')
# (2235, 'outlaw')
# (2236, 'percent')
# (2237, 'red')
# (2238, 'refrigerator')
# (2239, 'sham')
# (2240, 'spiral')
# (2241, 'upward')
# (2242, 'usury')
# (2243, 'acc')
# (2244, 'accessed')
# (2245, 'availability')
# (2246, 'binding')
# (2247, 'buisness')
# (2248, 'certify')
# (2249, 'cleared')
# (2250, 'comma')
# (2251, 'dati')
# (2252, 'dictate')
# (2253, 'edit')
# (2254, 'elderly')
# (2255, 'establish')
# (2256, 'exploitation')
# (2257, 'fool')
# (2258, 'foot')
# (2259, 'fore')
# (2260, 'gat')
# (2261, 'hey')
# (2262, 'honest')
# (2263, 'honour')
# (2264, 'institute')
# (2265, 'living')
# (2266, 'lye')
# (2267, 'mobility')
# (2268, 'muli')
# (2269, 'ori')
# (2270, 'outright')
# (2271, 'penny')
# (2272, 'pick')
# (2273, 'ple')
# (2274, 'poa')
# (2275, 'predator')
# (2276, 'pur')
# (2277, 'recieved')
# (2278, 'restriction')
# (2279, 'retrain')
# (2280, 'rough')
# (2281, 'shred')
# (2282, 'steak')
# (2283, 'successor')
# (2284, 'ted')
# (2285, 'threw')
# (2286, 'throw')
# (2287, 'unsigned')
# (2288, 'uphold')
# (2289, 'wil')
# (2290, 'truck')
# (2291, 'banner')
# (2292, 'browse')
# (2293, 'changed')
# (2294, 'prerequisite')
# (2295, 'listen')
# (2296, 'tag')
# (2297, 'talked')
# (2298, 'dishonest')
# (2299, 'truthful')
# (2300, 'empty')
# (2301, 'package')
# (2302, 'picture')
# (2303, 'pseudo')
# (2304, 'track')
# (2305, 'notary')
# (2306, 'verifies')
# (2307, 'appalled')
# (2308, 'countless')
# (2309, 'exhaust')
# (2310, 'facilitate')
# (2311, 'forever')
# (2312, 'kid')
# (2313, 'maybe')
# (2314, 'monitoring')
# (2315, 'noted')
# (2316, 'obvious')
# (2317, 'overlook')
# (2318, 'plead')
# (2319, 'regulatory')
# (2320, 'reopened')
# (2321, 'signed')
# (2322, 'thoroughly')
# (2323, 'trial')
# (2324, 'vacation')
# (2325, 'window')
# (2326, 'highway')
# (2327, 'holiday')
# (2328, 'labor')
# (2329, 'payroll')
# (2330, 'pushed')
# (2331, 'robbery')
# (2332, 'unconscionable')
# (2333, 'accuracy')
# (2334, 'commission')
# (2335, 'oll')
# (2336, 'wed')
# (2337, 'delinquency')
# (2338, 'identify')
# (2339, 'reaffirmation')
# (2340, 'necessitate')
# (2341, 'warn')
# (2342, 'background')
# (2343, 'blemish')
# (2344, 'bureaus')
# (2345, 'calculate')
# (2346, 'elsewhere')
# (2347, 'factor')
# (2348, 'glitch')
# (2349, 'mesh')
# (2350, 'plausible')
# (2351, 'reapplied')
# (2352, 'thrown')
# (2353, 'viability')
# (2354, 'chain')
# (2355, 'depositor')
# (2356, 'fdic')
# (2357, 'special')
# (2358, 'van')
# (2359, 'attempted')
# (2360, 'depth')
# (2361, 'differently')
# (2362, 'telling')
# (2363, 'arrest')
# (2364, 'dns')
# (2365, 'slew')
# (2366, 'tra')
# (2367, 'amaze')
# (2368, 'annual')
# (2369, 'carry')
# (2370, 'choice')
# (2371, 'clearing')
# (2372, 'defense')
# (2373, 'drawer')
# (2374, 'dresser')
# (2375, 'favorite')
# (2376, 'flagging')
# (2377, 'ideal')
# (2378, 'liberty')
# (2379, 'rely')
# (2380, 'shut')
# (2381, 'significance')
# (2382, 'sudden')
# (2383, 'suffer')
# (2384, 'suspense')
# (2385, 'target')
# (2386, 'trigger')
# (2387, 'illegally')
# (2388, 'medication')
# (2389, 'principal')
# (2390, 'caption')
# (2391, 'clarification')
# (2392, 'compliant')
# (2393, 'conflate')
# (2394, 'contains')
# (2395, 'fcb')
# (2396, 'permanent')
# (2397, 'ute')
# (2398, 'automobile')
# (2399, 'cushion')
# (2400, 'horrific')
# (2401, 'nowhere')
# (2402, 'adjustment')
# (2403, 'applicable')
# (2404, 'authentication')
# (2405, 'cease')
# (2406, 'claiming')
# (2407, 'cooperation')
# (2408, 'desist')
# (2409, 'determination')
# (2410, 'disadvantage')
# (2411, 'example')
# (2412, 'expressly')
# (2413, 'itemization')
# (2414, 'limitation')
# (2415, 'meantime')
# (2416, 'permit')
# (2417, 'purge')
# (2418, 'reduction')
# (2419, 'somebody')
# (2420, 'consume')
# (2421, 'historical')
# (2422, 'overcharge')
# (2423, 'rarely')
# (2424, 'repay')
# (2425, 'irony')
# (2426, 'simultaneously')
# (2427, 'surplus')
# (2428, 'excuse')
# (2429, 'hunch')
# (2430, 'reached')
# (2431, 'sneaker')
# (2432, 'traditional')
# (2433, 'discriminating')
# (2434, 'officer')
# (2435, 'opted')
# (2436, 'ratio')
# (2437, 'replied')
# (2438, 'somewhere')
# (2439, 'upper')
# (2440, 'abide')
# (2441, 'adverse')
# (2442, 'aggression')
# (2443, 'complainant')
# (2444, 'correction')
# (2445, 'counsel')
# (2446, 'eco')
# (2447, 'equal')
# (2448, 'harm')
# (2449, 'impede')
# (2450, 'justify')
# (2451, 'legally')
# (2452, 'moment')
# (2453, 'motif')
# (2454, 'prot')
# (2455, 'reform')
# (2456, 'regulator')
# (2457, 'reject')
# (2458, 'rejection')
# (2459, 'retaliation')
# (2460, 'retaliatory')
# (2461, 'severe')
# (2462, 'sustain')
# (2463, 'toward')
# (2464, 'violate')
# (2465, 'violated')
# (2466, 'workout')
# (2467, 'wrongdoing')
# (2468, 'air')
# (2469, 'blatantly')
# (2470, 'chooses')
# (2471, 'chronology')
# (2472, 'evaluated')
# (2473, 'finding')
# (2474, 'refundable')
# (2475, 'resubmit')
# (2476, 'summary')
# (2477, 'voucher')
# (2478, 'collector')
# (2479, 'michigan')
# (2480, 'reflected')
# (2481, 'beauty')
# (2482, 'hair')
# (2483, 'shoe')
# (2484, 'shop')
# (2485, 'stadium')
# (2486, 'wig')
# (2487, 'average')
# (2488, 'grid')
# (2489, 'movement')
# (2490, 'disappear')
# (2491, 'fixed')
# (2492, 'weekly')
# (2493, 'amiss')
# (2494, 'ample')
# (2495, 'assert')
# (2496, 'elevate')
# (2497, 'envelope')
# (2498, 'exists')
# (2499, 'front')
# (2500, 'absolute')
# (2501, 'beat')
# (2502, 'clause')
# (2503, 'cooperate')
# (2504, 'differ')
# (2505, 'dire')
# (2506, 'disservice')
# (2507, 'ditch')
# (2508, 'equivalent')
# (2509, 'examiner')
# (2510, 'fancy')
# (2511, 'handwrite')
# (2512, 'hardly')
# (2513, 'industry')
# (2514, 'insult')
# (2515, 'insurer')
# (2516, 'investment')
# (2517, 'lick')
# (2518, 'light')
# (2519, 'messy')
# (2520, 'nicer')
# (2521, 'optimistic')
# (2522, 'perk')
# (2523, 'physician')
# (2524, 'puts')
# (2525, 'reluctance')
# (2526, 'rub')
# (2527, 'salt')
# (2528, 'secondary')
# (2529, 'serve')
# (2530, 'sir')
# (2531, 'stamp')
# (2532, 'super')
# (2533, 'supposedly')
# (2534, 'uploaded')
# (2535, 'useless')
# (2536, 'wind')
# (2537, 'bitcoin')
# (2538, 'burger')
# (2539, 'grab')
# (2540, 'minnesota')
# (2541, 'near')
# (2542, 'quit')
# (2543, 'unlocked')
# (2544, 'phoned')
# (2545, 'reauthorized')
# (2546, 'retain')
# (2547, 'bar')
# (2548, 'beer')
# (2549, 'forged')
# (2550, 'gentleman')
# (2551, 'threaten')
# (2552, 'violence')
# (2553, 'arbitrarily')
# (2554, 'csr')
# (2555, 'endorsed')
# (2556, 'habitual')
# (2557, 'systemic')
# (2558, 'everytime')
# (2559, 'agony')
# (2560, 'arrange')
# (2561, 'fulfil')
# (2562, 'mental')
# (2563, 'virtual')
# (2564, 'allegedly')
# (2565, 'cst')
# (2566, 'download')
# (2567, 'intentionally')
# (2568, 'negatively')
# (2569, 'scheduled')
# (2570, 'cheated')
# (2571, 'personnel')
# (2572, 'postal')
# (2573, 'tire')
# (2574, 'baby')
# (2575, 'fianc')
# (2576, 'camera')
# (2577, 'investigator')
# (2578, 'jail')
# (2579, 'pray')
# (2580, 'scene')
# (2581, 'ten')
# (2582, 'boom')
# (2583, 'cation')
# (2584, 'dot')
# (2585, 'reservation')
# (2586, 'vanish')
# (2587, 'accepted')
# (2588, 'altitude')
# (2589, 'bed')
# (2590, 'broken')
# (2591, 'crew')
# (2592, 'disingenuous')
# (2593, 'economy')
# (2594, 'fixable')
# (2595, 'flat')
# (2596, 'function')
# (2597, 'functioned')
# (2598, 'inadequate')
# (2599, 'recline')
# (2600, 'stick')
# (2601, 'wholly')
# (2602, 'bond')
# (2603, 'certified')
# (2604, 'federally')
# (2605, 'ironically')
# (2606, 'resp')
# (2607, 'season')
# (2608, 'agreed')
# (2609, 'ball')
# (2610, 'bargain')
# (2611, 'convince')
# (2612, 'distress')
# (2613, 'emotional')
# (2614, 'eyes')
# (2615, 'focus')
# (2616, 'frequently')
# (2617, 'ill')
# (2618, 'lived')
# (2619, 'med')
# (2620, 'memo')
# (2621, 'responded')
# (2622, 'scar')
# (2623, 'slid')
# (2624, 'slide')
# (2625, 'wan')
# (2626, 'embezzle')
# (2627, 'pose')
# (2628, 'chief')
# (2629, 'mar')
# (2630, 'maryland')
# (2631, 'restitution')
# (2632, 'sponsor')
# (2633, 'supportive')
# (2634, 'withhold')
# (2635, 'advisable')
# (2636, 'appointment')
# (2637, 'florida')
# (2638, 'incorporation')
# (2639, 'washington')
# (2640, 'affected')
# (2641, 'annually')
# (2642, 'bin')
# (2643, 'calendar')
# (2644, 'coincidentally')
# (2645, 'esc')
# (2646, 'external')
# (2647, 'periodic')
# (2648, 'randomly')
# (2649, 'retention')
# (2650, 'temporarily')
# (2651, 'test')
# (2652, 'tion')
# (2653, 'unjustifiable')
# (2654, 'vis')
# (2655, 'volume')
# (2656, 'defective')
# (2657, 'downhill')
# (2658, 'favor')
# (2659, 'speaking')
# (2660, 'activation')
# (2661, 'chip')
# (2662, 'intercept')
# (2663, 'lax')
# (2664, 'replacement')
# (2665, 'surrogate')
# (2666, 'deed')
# (2667, 'divide')
# (2668, 'divorce')
# (2669, 'individually')
# (2670, 'perfect')
# (2671, 'ref')
# (2672, 'cdt')
# (2673, 'digits')
# (2674, 'remains')
# (2675, 'remind')
# (2676, 'submitted')
# (2677, 'unavailable')
# (2678, 'allotment')
# (2679, 'detach')
# (2680, 'dialog')
# (2681, 'emergency')
# (2682, 'impair')
# (2683, 'jump')
# (2684, 'paid')
# (2685, 'tdd')
# (2686, 'worker')
# (2687, 'blah')
# (2688, 'conflict')
# (2689, 'health')
# (2690, 'hrs')
# (2691, 'laziness')
# (2692, 'legit')
# (2693, 'meanwhile')
# (2694, 'million')
# (2695, 'screw')
# (2696, 'tow')
# (2697, 'cur')
# (2698, 'reo')
# (2699, 'ring')
# (2700, 'signer')
# (2701, 'arrogance')
# (2702, 'arrogant')
# (2703, 'bother')
# (2704, 'competent')
# (2705, 'decency')
# (2706, 'egregious')
# (2707, 'mad')
# (2708, 'mailbox')
# (2709, 'merchandise')
# (2710, 'misdemeanor')
# (2711, 'misinform')
# (2712, 'professionalism')
# (2713, 'receptive')
# (2714, 'recharge')
# (2715, 'renew')
# (2716, 'unprofessional')
# (2717, 'detect')
# (2718, 'revenue')
# (2719, 'bike')
# (2720, 'formally')
# (2721, 'girl')
# (2722, 'pickup')
# (2723, 'comfortable')
# (2724, 'mer')
# (2725, 'trustworthy')
# (2726, 'compromise')
# (2727, 'inept')
# (2728, 'penalty')
# (2729, 'ale')
# (2730, 'allege')
# (2731, 'atrocious')
# (2732, 'button')
# (2733, 'fru')
# (2734, 'got')
# (2735, 'indicated')
# (2736, 'misuse')
# (2737, 'pop')
# (2738, 'rat')
# (2739, 'reappeared')
# (2740, 'rou')
# (2741, 'str')
# (2742, 'transmission')
# (2743, 'transmit')
# (2744, 'funding')
# ...
# (10447, 'eternally')
# (10448, 'ford')
# (10449, 'apprise')
# (10450, 'despise')
# (10451, 'unprepared')
# (10452, 'epic')
# (10453, 'tolerance')
# (10454, 'statewide')
# (10455, 'brown')
# (10456, 'mud')
# (10457, 'specifics')
# (10458, 'undermines')
# (10459, 'sfr')
# (10460, 'incentives')
# (10461, 'nance')
# (10462, 'brin')
# (10463, 'established')
# (10464, 'elate')
# (10465, 'scant')
# (10466, 'intuition')
# (10467, 'racket')
# (10468, 'unwillingly')
# (10469, 'brutal')
# (10470, 'trier')
# (10471, 'rearranges')
# (10472, 'answers')
# (10473, 'attic')
# (10474, 'blast')
# (10475, 'insulation')
# (10476, 'layoff')
# (10477, 'postdate')
# (10478, 'soak')
# (10479, 'confine')
# (10480, 'elicit')
# (10481, 'babysit')
# (10482, 'converted')
# (10483, 'disastrous')
# (10484, 'stumble')
# (10485, 'yank')
# (10486, 'daughters')
# (10487, 'placate')
# (10488, 'bronze')
# (10489, 'syphon')
# (10490, 'sorriest')
# (10491, 'relive')
# (10492, 'eighth')
# (10493, 'recklessness')
# (10494, 'twelfth')
# (10495, 'flux')
# (10496, 'inordinate')
# (10497, 'fuzzy')
# (10498, 'peculiarity')
# (10499, 'aircraft')
# (10500, 'outrageously')
# (10501, 'inti')
# (10502, 'expenditure')
# (10503, 'mop')
# (10504, 'rail')
# (10505, 'consolidator')
# (10506, 'precludes')
# (10507, 'preclusion')
# (10508, 'riff')
# (10509, 'aesthetically')
# (10510, 'dive')
# (10511, 'exhaustive')
# (10512, 'heartbreaking')
# (10513, 'resolving')
# (10514, 'carrot')
# (10515, 'dangle')
# (10516, 'imminent')
# (10517, 'persecution')
# (10518, 'grammar')
# (10519, 'iri')
# (10520, 'underage')
# (10521, 'beverage')
# (10522, 'outgoing')
# (10523, 'lig')
# (10524, 'ethnic')
# (10525, 'forensic')
# (10526, 'usu')
# (10527, 'affirms')
# (10528, 'coll')
# (10529, 'taped')
# (10530, 'trunk')
# (10531, 'sarcastically')
# (10532, 'convene')
# (10533, 'neglectful')
# (10534, 'impacting')
# (10535, 'prompted')
# (10536, 'spray')
# (10537, 'walmart')
# (10538, 'baking')
# (10539, 'hearted')
# (10540, 'stan')
# (10541, 'disjoint')
# (10542, 'rescheduled')
# (10543, 'verb')
# (10544, 'astonishment')
# (10545, 'whip')
# (10546, 'blew')
# (10547, 'astonishingly')
# (10548, 'carelessly')
# (10549, 'devalues')
# (10550, 'unsuitable')
# (10551, 'bringing')
# (10552, 'demonstrated')
# (10553, 'opiate')
# (10554, 'consumes')
# (10555, 'pivotal')
# (10556, 'cheapest')
# (10557, 'misleads')
# (10558, 'miraculous')
# (10559, 'weed')
# (10560, 'sci')
# (10561, 'hiding')
# (10562, 'thom')
# (10563, 'township')
# (10564, 'humongous')
# (10565, 'tightly')
# (10566, 'hundredth')
# (10567, 'chamber')
# (10568, 'pointedly')
# (10569, 'reso')
# (10570, 'vel')
# (10571, 'pipeline')
# (10572, 'sal')
# (10573, 'moving')
# (10574, 'avoidance')
# (10575, 'extant')
# (10576, 'adjustor')
# (10577, 'totalled')
# (10578, 'intensely')
# (10579, 'tes')
# (10580, 'sizes')
# (10581, 'built')
# (10582, 'prom')
# (10583, 'nite')
# (10584, 'unproductive')
# (10585, 'lil')
# (10586, 'oro')
# (10587, 'inquisition')
# (10588, 'outlandish')
# (10589, 'pawn')
# (10590, 'colon')
# (10591, 'insanity')
# (10592, 'formulate')
# (10593, 'preoccupy')
# (10594, 'trapped')
# (10595, 'paychecks')
# (10596, 'minuscule')
# (10597, 'mut')
# (10598, 'unconstitutional')
# (10599, 'tore')
# (10600, 'jew')
# (10601, 'laborious')
# (10602, 'farce')
# (10603, 'subsidiaries')
# (10604, 'supervisory')
# (10605, 'screaming')
# (10606, 'arguably')
# (10607, 'punt')
# (10608, 'will')
# (10609, 'bean')
# (10610, 'ego')
# (10611, 'pouch')
# (10612, 'scatter')
# (10613, 'moor')
# (10614, 'sensor')
# (10615, 'backer')
# (10616, 'corrode')
# (10617, 'cortical')
# (10618, 'experimentation')
# (10619, 'implanted')
# (10620, 'pathways')
# (10621, 'peptide')
# (10622, 'photography')
# (10623, 'soundtrack')
# (10624, 'straightened')
# (10625, 'unus')
# (10626, 'abided')
# (10627, 'governed')
# (10628, 'remand')
# (10629, 'mir')
# (10630, 'gua')
# (10631, 'duel')
# (10632, 'shabbily')
# (10633, 'sincerity')
# (10634, 'pantry')
# (10635, 'anonymously')
# (10636, 'reseller')
# (10637, 'permitted')
# (10638, 'loosely')
# (10639, 'rce')
# (10640, 'cuff')
# (10641, 'apl')
# (10642, 'grudgingly')
# (10643, 'cusp')
# (10644, 'gro')
# (10645, 'heartbroken')
# (10646, 'reallocate')
# (10647, 'lia')
# (10648, 'programming')
# (10649, 'synchro')
# (10650, 'remuneration')
# (10651, 'rees')
# (10652, 'directory')
# (10653, 'proving')
# (10654, 'intrigue')
# (10655, 'unsympathetic')
# (10656, 'copying')
# (10657, 'municipal')
# (10658, 'lurch')
# (10659, 'alongside')
# (10660, 'tere')
# (10661, 'bake')
# (10662, 'pless')
# (10663, 'stupidly')
# (10664, 'selves')
# (10665, 'sequential')
# (10666, 'ripple')
# (10667, 'respiratory')
# (10668, 'nub')
# (10669, 'functionally')
# (10670, 'casinos')
# (10671, 'runarounds')
# (10672, 'sandwich')
# (10673, 'initialize')
# (10674, 'abandonment')
# (10675, 'buzz')
# (10676, 'reconnect')
# (10677, 'psyche')
# (10678, 'swoop')
# (10679, 'tar')
# (10680, 'learns')
# (10681, 'refurnish')
# (10682, 'complicated')
# (10683, 'corn')
# (10684, 'attacked')
# (10685, 'painstakingly')
# (10686, 'recitation')
# (10687, 'tidy')
# (10688, 'awaited')
# (10689, 'excellence')
# (10690, 'fsa')
# (10691, 'mbs')
# (10692, 'healthier')
# (10693, 'congr')
# (10694, 'publicity')
# (10695, 'marshall')
# (10696, 'arcane')
# (10697, 'mei')
# (10698, 'nui')
# (10699, 'aviation')
# (10700, 'hallway')
# (10701, 'perpetuating')
# (10702, 'quail')
# (10703, 'rigid')
# (10704, 'spuriously')
# (10705, 'concession')
# (10706, 'digging')
# (10707, 'boa')
# (10708, 'measly')
# (10709, 'drawls')
# (10710, 'bitter')
# (10711, 'condescending')
# (10712, 'yelled')
# (10713, 'knowle')
# (10714, 'mun')
# (10715, 'refiling')
# (10716, 'northern')
# (10717, 'deliveries')
# (10718, 'dod')
# (10719, 'diagram')
# (10720, 'fling')
# (10721, 'vein')
# (10722, 'cryptography')
# (10723, 'databases')
# (10724, 'optimization')
# (10725, 'intense')
# (10726, 'benefitted')
# (10727, 'catalog')
# (10728, 'intra')
# (10729, 'nevermind')
# (10730, 'faa')
# (10731, 'barcode')
# (10732, 'unreadable')
# (10733, 'disseminate')
# (10734, 'describing')
# (10735, 'gripe')
# (10736, 'rage')
# (10737, 'ota')
# (10738, 'totalling')
# (10739, 'chunk')
# (10740, 'defined')
# (10741, 'learnt')
# (10742, 'avoided')
# (10743, 'wends')
# (10744, 'cave')
# (10745, 'consensual')
# (10746, 'stake')
# (10747, 'boys')
# (10748, 'yelling')
# (10749, 'wield')
# (10750, 'sixteen')
# (10751, 'annex')
# (10752, 'childcare')
# (10753, 'stead')
# (10754, 'installers')
# (10755, 'contentious')
# (10756, 'maintained')
# (10757, 'hoped')
# (10758, 'disbursed')
# (10759, 'repaid')
# (10760, 'underwear')
# (10761, 'stealthily')
# (10762, 'fallow')
# (10763, 'bulldog')
# (10764, 'telegram')
# (10765, 'migrate')
# (10766, 'const')
# (10767, 'overridden')
# (10768, 'agian')
# (10769, 'fabricated')
# (10770, 'pso')
# (10771, 'aliz')
# (10772, 'stepped')
# (10773, 'testament')
# (10774, 'appellate')
# (10775, 'intimation')
# (10776, 'cheaply')
# (10777, 'employe')
# (10778, 'prop')
# (10779, 'sketch')
# (10780, 'begrudge')
# (10781, 'heirs')
# (10782, 'drone')
# (10783, 'shenanigan')
# (10784, 'census')
# (10785, 'doodle')
# (10786, 'fateful')
# (10787, 'marina')
# (10788, 'retrievable')
# (10789, 'reissued')
# (10790, 'argues')
# (10791, 'empire')
# (10792, 'plaint')
# (10793, 'agen')
# (10794, 'sex')
# (10795, 'lian')
# (10796, 'gathering')
# (10797, 'wha')
# (10798, 'liked')
# (10799, 'subst')
# (10800, 'coarse')
# (10801, 'typifies')
# (10802, 'ike')
# (10803, 'vacated')
# (10804, 'withdrawals')
# (10805, 'rotor')
# (10806, 'connectivity')
# (10807, 'fragmentation')
# (10808, 'mann')
# (10809, 'vrs')
# (10810, 'expenditures')
# (10811, 'dust')
# (10812, 'transcribed')
# (10813, 'outraged')
# (10814, 'diesel')
# (10815, 'credulity')
# (10816, 'semantic')
# (10817, 'copies')
# (10818, 'forms')
# (10819, 'protracted')
# (10820, 'capped')
# (10821, 'circled')
# (10822, 'overdraws')
# (10823, 'departmental')
# (10824, 'objectively')
# (10825, 'quantitative')
# (10826, 'strategic')
# (10827, 'aue')
# (10828, 'shaft')
# (10829, 'confirmatory')
# (10830, 'implicitly')
# (10831, 'initiating')
# (10832, 'pecuniary')
# (10833, 'restraining')
# (10834, 'predate')
# (10835, 'dub')
# (10836, 'statistically')
# (10837, 'expiry')
# (10838, 'potato')
# (10839, 'reoccur')
# (10840, 'coherent')
# (10841, 'litany')
# (10842, 'minorities')
# (10843, 'unload')
# (10844, 'suburb')
# (10845, 'unc')
# (10846, 'obsessively')
# (10847, 'imagination')
# (10848, 'flawlessly')
# (10849, 'negotiating')
# (10850, 'tiga')
# (10851, 'interchange')
# (10852, 'appease')
# (10853, 'disassociate')
# (10854, 'erode')
# (10855, 'hoe')
# (10856, 'hab')
# (10857, 'overreact')
# (10858, 'plummeted')
# (10859, 'provincial')
# (10860, 'unnec')
# (10861, 'revers')
# (10862, 'laying')
# (10863, 'businessman')
# (10864, 'computation')
# (10865, 'lev')
# (10866, 'indebted')
# (10867, 'shakedown')
# (10868, 'averse')
# (10869, 'saddest')
# (10870, 'rationally')
# (10871, 'reflective')
# (10872, 'impaired')
# (10873, 'latency')
# (10874, 'enclosing')
# (10875, 'frightening')
# (10876, 'drywall')
# (10877, 'ocean')
# (10878, 'umer')
# (10879, 'reaffirmed')
# (10880, 'overpriced')
# (10881, 'legendary')
# (10882, 'perimeter')
# (10883, 'shy')
# (10884, 'formality')
# (10885, 'changeover')
# (10886, 'dupl')
# (10887, 'ile')
# (10888, 'underestimated')
# (10889, 'combative')
# (10890, 'undeclared')
# (10891, 'ponzi')
# (10892, 'investigates')
# (10893, 'lani')
# (10894, 'tsp')
# (10895, 'enjoin')
# (10896, 'falsifies')
# (10897, 'rio')
# (10898, 'belittled')
# (10899, 'unceremoniously')
# (10900, 'deprived')
# (10901, 'nose')
# (10902, 'objected')
# (10903, 'collectibles')
# (10904, 'controvert')
# (10905, 'dope')
# (10906, 'fsi')
# (10907, 'looser')
# (10908, 'raggedly')
# (10909, 'raggedy')
# (10910, 'skimmed')
# (10911, 'syndicat')
# (10912, 'syndicate')
# (10913, 'spew')
# (10914, 'equates')
# (10915, 'visibly')
# (10916, 'gory')
# (10917, 'foreseen')
# (10918, 'mundane')
# (10919, 'consumption')
# (10920, 'explode')
# (10921, 'penn')
# (10922, 'ince')
# (10923, 'vehement')
# (10924, 'whack')
# (10925, 'mend')
# (10926, 'parallel')
# (10927, 'chasse')
# (10928, 'unstated')
# (10929, 'stateside')
# (10930, 'forcible')
# (10931, 'jug')
# (10932, 'unearned')
# (10933, 'pilot')
# (10934, 'optimism')
# (10935, 'razor')
# (10936, 'demolition')
# (10937, 'irrationally')
# (10938, 'trn')
# (10939, 'fes')
# (10940, 'chek')
# (10941, 'forbids')
# (10942, 'humiliated')
# (10943, 'listened')
# (10944, 'hurri')
# (10945, 'caliber')
# (10946, 'influential')
# (10947, 'imperfect')
# (10948, 'gional')
# (10949, 'confound')
# (10950, 'inadequately')
# (10951, 'scoff')
# (10952, 'organ')
# (10953, 'furtherance')
# (10954, 'preempt')
# (10955, 'prerequisites')
# (10956, 'delusion')
# (10957, 'dvd')
# (10958, 'wring')
# (10959, 'bailed')
# (10960, 'uncertainly')
# (10961, 'overrides')
# (10962, 'pla')
# (10963, 'physic')
# (10964, 'enhancement')
# (10965, 'translated')
# (10966, 'fish')
# (10967, 'accomodate')
# (10968, 'snowstorm')
# (10969, 'repeal')
# (10970, 'imprisoned')
# (10971, 'pedal')
# (10972, 'hysterical')
# (10973, 'celebration')
# (10974, 'intercontinental')
# (10975, 'delivering')
# (10976, 'organizational')
# (10977, 'origins')
# (10978, 'refresh')
# (10979, 'accepting')
# (10980, 'tully')
# (10981, 'triplicate')
# (10982, 'veterinarian')
# (10983, 'deviation')
# (10984, 'eerily')
# (10985, 'pernicious')
# (10986, 'asterisk')
# (10987, 'crawl')
# (10988, 'disreputable')
# (10989, 'turbo')
# (10990, 'rae')
# (10991, 'jog')
# (10992, 'latin')
# (10993, 'horr')
# (10994, 'eighteen')
# (10995, 'presentable')
# (10996, 'bsc')
# (10997, 'ica')
# (10998, 'ltd')
# (10999, 'synthetic')
# (11000, 'knee')
# (11001, 'oblivious')
# (11002, 'disrepair')
# (11003, 'deadbeat')
# (11004, 'heaven')
# (11005, 'intervenes')
# (11006, 'riddle')
# (11007, 'hooray')
# (11008, 'ole')
# (11009, 'rchen')
# (11010, 'susposed')
# (11011, 'tempor')
# (11012, 'discontent')
# (11013, 'agriculture')
# (11014, 'histories')
# (11015, 'communicative')
# (11016, 'prohibited')
# (11017, 'flawed')
# (11018, 'quire')
# (11019, 'berate')
# (11020, 'deepen')
# (11021, 'unintentional')
# (11022, 'edi')
# (11023, 'stricter')
# (11024, 'usb')
# (11025, 'flout')
# (11026, 'switching')
# (11027, 'bor')
# (11028, 'hectic')
# (11029, 'nul')
# (11030, 'flooding')
# (11031, 'generically')
# (11032, 'exorbitantly')
# (11033, 'revere')
# (11034, 'arisen')
# (11035, 'pronounce')
# (11036, 'ulcer')
# (11037, 'leach')
# (11038, 'septic')
# (11039, 'opr')
# (11040, 'hog')
# (11041, 'mts')
# (11042, 'regurgitate')
# (11043, 'slighted')
# (11044, 'disarray')
# (11045, 'appa')
# (11046, 'sinking')
# (11047, 'endorsements')
# (11048, 'assailant')
# (11049, 'overzealous')
# (11050, 'precipitate')
# (11051, 'whey')
# (11052, 'vested')
# (11053, 'confrontational')
# (11054, 'furnishes')
# (11055, 'inequitable')
# (11056, 'indorsement')
# (11057, 'benefitting')
# (11058, 'treasure')
# (11059, 'manet')
# (11060, 'recasts')
# (11061, 'nigh')
# (11062, 'suburban')
# (11063, 'unlucky')
# (11064, 'woe')
# (11065, 'demoralize')
# (11066, 'markup')
# (11067, 'declaratory')
# (11068, 'eradicate')
# (11069, 'jest')
# (11070, 'friendlier')
# (11071, 'approximation')
# (11072, 'jammed')
# (11073, 'grit')
# (11074, 'gee')
# (11075, 'snafu')
# (11076, 'ani')
# (11077, 'descendant')
# (11078, 'ruc')
# (11079, 'attentive')
# (11080, 'atrociously')
# (11081, 'proposed')
# (11082, 'personalized')
# (11083, 'prejudicial')
# (11084, 'ancient')
# (11085, 'instituted')
# (11086, 'quickness')
# (11087, 'ccs')
# (11088, 'misapplies')
# (11089, 'bone')
# (11090, 'didi')
# (11091, 'nat')
# (11092, 'posed')
# (11093, 'snk')
# (11094, 'inasmuch')
# (11095, 'felonious')
# (11096, 'psa')
# (11097, 'asbestos')
# (11098, 'evacuation')
# (11099, 'conceivable')
# (11100, 'inclination')
# (11101, 'zap')
# (11102, 'undermined')
# (11103, 'scribe')
# (11104, 'segregation')
# (11105, 'sigh')
# (11106, 'paralyze')
# (11107, 'amputation')
# (11108, 'reconstruction')
# (11109, 'loner')
# (11110, 'buffer')
# (11111, 'depletion')
# (11112, 'enjoyment')
# (11113, 'simultaneous')
# (11114, 'believed')
# (11115, 'whir')
# (11116, 'connive')
# (11117, 'passion')
# (11118, 'commercially')
# (11119, 'contra')
# (11120, 'freer')
# (11121, 'statistical')
# (11122, 'western')
# (11123, 'joking')
# (11124, 'applicants')
# (11125, 'maria')
# (11126, 'drew')
# (11127, 'wider')
# (11128, 'snide')
# (11129, 'village')
# (11130, 'sgi')
# (11131, 'incomprehensibly')
# (11132, 'unbiased')
# (11133, 'submits')
# (11134, 'legislate')
# (11135, 'pizzeria')
# (11136, 'manpower')
# (11137, 'ply')
# (11138, 'colle')
# (11139, 'turm')
# (11140, 'whist')
# (11141, 'escalations')
# (11142, 'misquote')
# (11143, 'jeopardizes')
# (11144, 'heartache')
# (11145, 'exclamation')
# (11146, 'topmost')
# (11147, 'camouflage')
# (11148, 'litter')
# (11149, 'helpfully')
# (11150, 'bel')
# (11151, 'btc')
# (11152, 'pitfall')
# (11153, 'uni')
# (11154, 'chr')
# (11155, 'cooperating')
# (11156, 'remitted')
# (11157, 'spelled')
# (11158, 'dispossess')
# (11159, 'fuse')
# (11160, 'insulate')
# (11161, 'impartially')
# (11162, 'stealth')
# (11163, 'laye')
# (11164, 'courtroom')
# (11165, 'hindrance')
# (11166, 'kicked')
# (11167, 'nanny')
# (11168, 'debilitate')
# (11169, 'convoluted')
# (11170, 'analyzed')
# (11171, 'royally')
# (11172, 'rover')
# (11173, 'escalating')
# (11174, 'seventeen')
# (11175, 'entrapment')
# (11176, 'ivy')
# (11177, 'interrogation')
# (11178, 'facially')
# (11179, 'breathing')
# (11180, 'grieve')
# (11181, 'newness')
# (11182, 'garden')
# (11183, 'simplest')
# (11184, 'launching')
# (11185, 'quits')
# (11186, 'conservation')
# (11187, 'equitably')
# (11188, 'accredited')
# (11189, 'secretive')
# (11190, 'embroil')
# (11191, 'profiting')
# (11192, 'derived')
# (11193, 'unidentifiable')
# (11194, 'reimburses')
# (11195, 'shou')
# (11196, 'oust')
# (11197, 'imprisonment')
# (11198, 'enc')
# (11199, 'discourse')
# (11200, 'coco')
# (11201, 'transgender')
# (11202, 'agate')
# (11203, 'reorganization')
# (11204, 'kangaroo')
# (11205, 'volunteered')
# (11206, 'tread')
# (11207, 'fruitful')
# (11208, 'recliner')
# (11209, 'pencil')
# (11210, 'totalitarian')
# (11211, 'anise')
# (11212, 'lookout')
# (11213, 'pretending')
# (11214, 'theatre')
# (11215, 'pri')
# (11216, 'deluxe')
# (11217, 'intrigued')
# (11218, 'premiss')
# (11219, 'surroundings')
# (11220, 'behavioral')
# (11221, 'parasitic')
# (11222, 'scientific')
# (11223, 'levied')
# (11224, 'invention')
# (11225, 'prosperous')
# (11226, 'distro')
# (11227, 'powerlessness')
# (11228, 'breakup')
# (11229, 'midterm')
# (11230, 'leech')
# (11231, 'observance')
# (11232, 'logistical')
# (11233, 'fined')
# (11234, 'invoked')
# (11235, 'demonstration')
# (11236, 'costing')
# (11237, 'sidestep')
# (11238, 'ceramic')
# (11239, 'caseworker')
# (11240, 'wrangler')
# (11241, 'allusion')
# (11242, 'disgruntle')
# (11243, 'facto')
# (11244, 'redundancy')
# (11245, 'gust')
# (11246, 'navi')
# (11247, 'anf')
# (11248, 'imation')
# (11249, 'apprised')
# (11250, 'consequent')
# (11251, 'childs')
# (11252, 'minimus')
# (11253, 'cleanliness')
# (11254, 'filth')
# (11255, 'adequacy')
# (11256, 'flu')
# (11257, 'performs')
# (11258, 'tom')
# (11259, 'midi')
# (11260, 'vera')
# (11261, 'antagonistic')
# (11262, 'odor')
# (11263, 'stereotype')
# (11264, 'naca')
# (11265, 'ascribe')
# (11266, 'cognitive')
# (11267, 'degradation')
# (11268, 'regretful')
# (11269, 'prank')
# (11270, 'sable')
# (11271, 'unyielding')
# (11272, 'export')

# %%
texts = df['preprocessed_text'].str.split(' ')

corpus = [load_lda_id2word.doc2bow(text) for text in texts]

document_num = 17
bow_doc_x = corpus[document_num]

for i in range(len(bow_doc_x)):
    print('Word {} ("{}") appears {} time.'.format(bow_doc_x[i][0],
    load_lda_id2word[bow_doc_x[i][0]],
    bow_doc_x[i][1]))
# Out:
# Word 1 ("account") appears 1 time.
# Word 6 ("bank") appears 1 time.
# Word 7 ("card") appears 1 time.
# Word 119 ("check") appears 1 time.
# Word 124 ("deposit") appears 1 time.
# Word 127 ("money") appears 1 time.
# Word 134 ("say") appears 1 time.
# Word 136 ("take") appears 1 time.
# Word 190 ("realize") appears 1 time.
# Word 290 ("email") appears 1 time.
# Word 441 ("today") appears 1 time.
# Word 463 ("miss") appears 1 time.

# %% [markdown]
# # LDA

# %%
load_lda[bow_doc_x][0]
# Out:
# [(13, 0.09195252), (22, 0.3652678), (25, 0.31209028), (28, 0.16255431)]

# %%
for index, score in sorted(load_lda[bow_doc_x][0], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic {:3d}: {}".format(score, index, load_lda.print_topic(index, 5)))
# Out:
# Score: 0.36522209644317627	 Topic  22: 0.049*"money" + 0.036*"get" + 0.024*"account" + 0.024*"bank" + 0.023*"say"
# Score: 0.312234491109848	 Topic  25: 0.118*"check" + 0.048*"deposit" + 0.047*"bank" + 0.043*"account" + 0.032*"fund"
# Score: 0.1624535620212555	 Topic  28: 0.074*"card" + 0.048*"debit" + 0.031*"atm" + 0.027*"account" + 0.024*"use"
# Score: 0.0919547900557518	 Topic  13: 0.073*"email" + 0.041*"send" + 0.036*"message" + 0.032*"address" + 0.026*"number"

# %% [markdown]
# # NMF

# %%
load_nmf[bow_doc_x]
# Out:
# [(0, 0.025997716189227405),
#  (2, 0.04749748742572338),
#  (4, 0.1611679735736758),
#  (5, 0.2523993759224312),
#  (7, 0.07604999347470942),
#  (8, 0.08218377258963519),
#  (9, 0.04191751718605628),
#  (10, 0.08251921967412937),
#  (11, 0.12145675534223431),
#  (12, 0.013621791630664997),
#  (14, 0.08878100936061033)]

# %%
for index, score in sorted(load_nmf[bow_doc_x], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic {:3d}: {}".format(score, index, load_nmf.print_topic(index, 5)))
# Out:
# Score: 0.23983018601938977	 Topic   5: 0.066*"account" + 0.053*"bank" + 0.041*"fraud" + 0.035*"money" + 0.035*"charge"
# Score: 0.15995444541008658	 Topic   4: 0.190*"check" + 0.043*"deposit" + 0.030*"day" + 0.025*"fund" + 0.018*"cash"
# Score: 0.11641518338921292	 Topic  11: 0.062*"bank" + 0.034*"send" + 0.032*"would" + 0.029*"tell" + 0.021*"money"
# Score: 0.09236939137737156	 Topic  14: 0.224*"account" + 0.026*"close" + 0.019*"open" + 0.015*"fund" + 0.012*"branch"
# Score: 0.0869759977276078	 Topic  10: 0.076*"card" + 0.046*"make" + 0.040*"transaction" + 0.038*"balance" + 0.033*"fee"
# Score: 0.07848206487675408	 Topic   8: 0.149*"card" + 0.019*"service" + 0.016*"use" + 0.014*"fraud" + 0.014*"charge"
# Score: 0.07147723375312962	 Topic   7: 0.114*"account" + 0.112*"credit" + 0.037*"report" + 0.035*"close" + 0.030*"open"
# Score: 0.05449411773037099	 Topic   2: 0.043*"call" + 0.043*"would" + 0.042*"get" + 0.037*"say" + 0.026*"tell"
# Score: 0.042079191184866936	 Topic   9: 0.056*"claim" + 0.024*"call" + 0.021*"number" + 0.017*"department" + 0.017*"transaction"
# Score: 0.02829610144612058	 Topic   0: 0.148*"payment" + 0.049*"bank" + 0.035*"mortgage" + 0.032*"make" + 0.031*"pay"
# Score: 0.019088734747343246	 Topic  12: 0.208*"credit" + 0.048*"card" + 0.019*"charge" + 0.014*"consumer" + 0.014*"report"
# Score: 0.010537352337745822	 Topic  13: 0.068*"call" + 0.044*"receive" + 0.031*"tell" + 0.025*"day" + 0.018*"service"

# %% [markdown]
# # Top2Vec

# %%
t2v_topics_words, t2v_word_scores, t2v_topic_scores, t2v_topic_nums =load_t2v.query_topics(removed_mask[42],1)
t2v_predict_words_df = pd.DataFrame({'topics_words':list(t2v_topics_words[0]),'word_scores':list(t2v_word_scores[0])})
print("Predicted Topic Number {}\t Score: {}".format(t2v_topic_nums[0],t2v_topic_scores[0]))
t2v_predict_words_df
# Out:
# Predicted Topic Number 0	 Score: 0.5731476545333862
#     topics_words  word_scores
# 0    chexsystems     0.463706
# 1           cfpb     0.436052
# 2        autopay     0.426086
# 3           bofa     0.413042
# 4       lifelock     0.400830
# 5           usaa     0.386326
# 6       citibank     0.385421
# 7         repoed     0.382002
# 8          chase     0.378646
# 9           wamu     0.377880
# 10     overdrawn     0.377004
# 11           kyc     0.371406
# 12    wellsfargo     0.370528
# 13    transunion     0.369708
# 14   garnishment     0.365811
# 15   preapproval     0.359470
# 16           pnc     0.356574
# 17      experian     0.356134
# 18   chargebacks     0.355572
# 19        echeck     0.353631
# 20      churning     0.348665
# 21     defaulted     0.347958
# 22          citi     0.347406
# 23   overdrafted     0.345139
# 24  garnishments     0.340314
# 25    overdrafts     0.339625
# 26    chargeback     0.339039
# 27     overdraft     0.338955
# 28     garnished     0.334208
# 29    refinanced     0.330932
# 30          bank     0.330058
# 31     defrauded     0.327841
# 32          fdic     0.327814
# 33      creditor     0.326286
# 34     creditors     0.326103
# 35         heloc     0.324513
# 36       banking     0.324255
# 37   reposession     0.323152
# 38          refi     0.323059
# 39     insolvent     0.321851
# 40       equifax     0.321345
# 41    creditcard     0.320289
# 42       debtors     0.317693
# 43          amex     0.317626
# 44   receivables     0.317157
# 45     santander     0.315414
# 46      overdraw     0.308723
# 47    fraudsters     0.308647
# 48        lender     0.308562
# 49          hsbc     0.307352

# %% [markdown]
# # BERTopic

# %%
removed_mask[42]
# Out:
# 'My card went missing and i didnt realize it until today, i checked my email and they said there has been deposits and money taken out again. I had {$400.00} in my bank account and its gone.'

# %%
predicted_topics, predicted_probs = load_bertopic.transform(removed_mask[42])

# %%
predicted_topics
# Out:
# array([0], dtype=int64)

# %%
predicted_probs
# Out:
# array([0.5369783], dtype=float32)

# %%
btp_info = load_bertopic.get_topic_info()
btp_info
# Out:
#     Topic  Count                                    Name  \
# 0      -1  10960                        -1_the_to_and_my
# 1       0   5542                         0_the_to_and_my
# 2       1    695            1_fees_overdraft_account_fee
# 3       2    349        2_modification_loan_mortgage_the
# 4       3    287                3_amazon_card_credit_the
# ..    ...    ...                                     ...
# 58     57     15       57_tax_property tax_vehicle_lease
# 59     58     15  58_stimulus_irs_the irs_stimulus check
# 60     59     15       59_jpmchase_il_my parents_parents
# 61     60     15                     60_wamu_the_of_loan
# 62     61     15        61_unemployment_my_funds_account
#
#                                        Representation  Representative_Docs
# 0    [the, to, and, my, that, was, chase, of, in, on]                  NaN
# 1   [the, to, and, my, chase, that, was, on, credi...                  NaN
# 2   [fees, overdraft, account, fee, the, to, my, m...                  NaN
# 3   [modification, loan, mortgage, the, to, and, m...                  NaN
# 4   [amazon, card, credit, the, to, and, chase, my...                  NaN
# ..                                                ...                  ...
# 58  [tax, property tax, vehicle, lease, property, ...                  NaN
# 59  [stimulus, irs, the irs, stimulus check, check...                  NaN
# 60  [jpmchase, il, my parents, parents, jpmchase t...                  NaN
# 61  [wamu, the, of, loan, to, in, homeowner, was, ...                  NaN
# 62  [unemployment, my, funds, account, my unemploy...                  NaN
#
# [63 rows x 5 columns]

# %%
# predicted_topic = btp_info[btp_info.Topic==predicted_topics[0]]
btp_info["Name"][predicted_topics[0]+1]
# f'Topic {predicted_topic["Name"]}'
# Out:
# '0_the_to_and_my'

# %%
btp_info["Representation"][predicted_topics[0]+1]
# Out:
# ['the', 'to', 'and', 'my', 'chase', 'that', 'was', 'on', 'credit', 'of']
